# %%
import numpy as np
import pandas as pd
from alg_repository.data_importer import DataImporter as di
import os
file_names = os.listdir('CSV file rep')
file_path = 'CSV file rep/'
current_A_angle_begin = di(',',file_path + file_names[0]).main_process()
current_A_angle_end = di(',',file_path + file_names[1]).main_process()
current_B_angle_begin = di(',',file_path + file_names[2]).main_process()
current_B_angle_end = di(',',file_path + file_names[3]).main_process()
current_C_angle_begin = di(',',file_path + file_names[4]).main_process()
current_C_angle_end = di(',',file_path + file_names[5]).main_process()
current_A_begin = di(',',file_path + file_names[6]).main_process()
current_A_end = di(',',file_path + file_names[7]).main_process()
current_B_begin = di(',',file_path + file_names[8]).main_process()
current_B_end = di(',',file_path + file_names[9]).main_process()
current_C_begin = di(',',file_path + file_names[10]).main_process()
current_C_end = di(',',file_path + file_names[11]).main_process()
voltage_A_angle_begin = di(',',file_path + file_names[12]).main_process()
voltage_A_angle_end = di(',',file_path + file_names[13]).main_process()
voltage_B_angle_begin = di(',',file_path + file_names[14]).main_process()
voltage_B_angle_end = di(',',file_path + file_names[15]).main_process()
voltage_C_angle_begin = di(',',file_path + file_names[16]).main_process()
voltage_C_angle_end = di(',',file_path + file_names[17]).main_process()
voltage_A_begin = di(',',file_path + file_names[18]).main_process()
voltage_A_end = di(',',file_path + file_names[19]).main_process()
voltage_B_begin = di(',',file_path + file_names[20]).main_process()
voltage_B_end = di(',',file_path + file_names[21]).main_process()
voltage_C_begin = di(',',file_path + file_names[22]).main_process()
voltage_C_end = di(',',file_path + file_names[23]).main_process()
time = di(',',file_path + file_names[24]).main_process()
time['Time'] = pd.to_datetime(time['Time'], unit='s', origin='unix').dt.strftime('%S.%f')

def rename_columns(data_current):
    columns_name = []
    for indx in range(len(data_current.columns)):
        columns_name.append('exp ' + str(indx + 1))

    data_current.columns = columns_name
    return data_current

current_A_begin = rename_columns(current_A_begin)
current_B_begin = rename_columns(current_B_begin)
current_C_begin = rename_columns(current_C_begin)
current_A_angle_begin = rename_columns(current_A_angle_begin)
current_A_angle_end =  rename_columns(current_A_angle_end)
current_B_angle_begin = rename_columns(current_B_angle_begin)
current_B_angle_end = rename_columns(current_B_angle_end)
current_C_angle_begin = rename_columns(current_C_angle_begin)
current_C_angle_end = rename_columns(current_C_angle_end)
current_A_begin = rename_columns(current_A_begin)
current_A_end = rename_columns(current_A_end)
current_B_begin = rename_columns(current_B_begin)
current_B_end = rename_columns(current_B_end)
current_C_begin = rename_columns(current_C_begin)
current_C_end = rename_columns(current_C_end)
voltage_A_angle_begin = rename_columns(voltage_A_angle_begin)
voltage_A_angle_end = rename_columns(voltage_A_angle_end)
voltage_B_angle_begin = rename_columns(voltage_B_angle_begin)
voltage_B_angle_end = rename_columns(voltage_B_angle_end)
voltage_C_angle_begin = rename_columns(voltage_C_angle_begin)
voltage_C_angle_end = rename_columns(voltage_C_angle_end)
voltage_A_begin = rename_columns(voltage_A_begin)
voltage_A_end = rename_columns(voltage_A_end)
voltage_B_begin = rename_columns(voltage_B_begin)
voltage_B_end = rename_columns(voltage_B_end)
voltage_C_begin = rename_columns(voltage_C_begin)
voltage_C_end = rename_columns(voltage_C_end)

# %%
# Инициализация временных переменных для выгрузки экспериментов
data_current_A_beg = []
data_current_B_beg = []
data_current_C_beg = []
data_current_A_end = []
data_current_B_end = []
data_current_C_end = []
data_voltage_A_beg = []
data_voltage_B_beg = []
data_voltage_C_beg = []
data_voltage_A_end = []
data_voltage_B_end = []
data_voltage_C_end = []
data_current_A_beg_ang = []
data_current_B_beg_ang = []
data_current_C_beg_ang = []
data_current_A_end_ang = []
data_current_B_end_ang = []
data_current_C_end_ang = []
data_voltage_A_beg_ang = []
data_voltage_B_beg_ang = []
data_voltage_C_beg_ang = []
data_voltage_A_end_ang = []
data_voltage_B_end_ang = []
data_voltage_C_end_ang = []


# Сборка групп данных
for indx in range(3000):
    # Подгрузка данных и сбор их в отдельные ячейки по экспериментам
    exp_name = 'exp ' + str(indx + 1)
    data_current_A_beg.append([current_A_begin[exp_name].reset_index(drop=True).values])
    data_current_B_beg.append([current_B_begin[exp_name].reset_index(drop=True).values])
    data_current_C_beg.append([current_C_begin[exp_name].reset_index(drop=True).values])
    data_current_A_end.append([current_A_end[exp_name].reset_index(drop=True).values])
    data_current_B_end.append([current_B_end[exp_name].reset_index(drop=True).values])
    data_current_C_end.append([current_C_end[exp_name].reset_index(drop=True).values])
    data_voltage_A_beg.append([voltage_A_begin[exp_name].reset_index(drop=True).values])
    data_voltage_B_beg.append([voltage_B_begin[exp_name].reset_index(drop=True).values])
    data_voltage_C_beg.append([voltage_C_begin[exp_name].reset_index(drop=True).values])
    data_voltage_A_end.append([voltage_A_end[exp_name].reset_index(drop=True).values])
    data_voltage_B_end.append([voltage_B_end[exp_name].reset_index(drop=True).values])
    data_voltage_C_end.append([voltage_C_end[exp_name].reset_index(drop=True).values])
    data_current_A_beg_ang.append([current_A_angle_begin[exp_name].reset_index(drop=True).values])
    data_current_B_beg_ang.append([current_B_angle_begin[exp_name].reset_index(drop=True).values])
    data_current_C_beg_ang.append([current_C_angle_begin[exp_name].reset_index(drop=True).values])
    data_current_A_end_ang.append([current_A_angle_end[exp_name].reset_index(drop=True).values])
    data_current_B_end_ang.append([current_B_angle_end[exp_name].reset_index(drop=True).values])
    data_current_C_end_ang.append([current_C_angle_end[exp_name].reset_index(drop=True).values])
    data_voltage_A_beg_ang.append([voltage_A_angle_begin[exp_name].reset_index(drop=True).values])
    data_voltage_B_beg_ang.append([voltage_B_angle_begin[exp_name].reset_index(drop=True).values])
    data_voltage_C_beg_ang.append([voltage_C_angle_begin[exp_name].reset_index(drop=True).values])
    data_voltage_A_end_ang.append([voltage_A_angle_end[exp_name].reset_index(drop=True).values])
    data_voltage_B_end_ang.append([voltage_B_angle_end[exp_name].reset_index(drop=True).values])
    data_voltage_C_end_ang.append([voltage_C_angle_end[exp_name].reset_index(drop=True).values])

# Сборка данных в один список
data_current_beg = np.concatenate((np.array(data_current_A_beg),
                                  np.array(data_current_B_beg),
                                  np.array(data_current_C_beg)), axis = 1)
data_current_end = np.concatenate((np.array(data_current_A_end),
                                  np.array(data_current_B_end),
                                  np.array(data_current_C_end)), axis = 1)
data_voltage_beg = np.concatenate((np.array(data_voltage_A_beg),
                                  np.array(data_voltage_B_beg),
                                  np.array(data_voltage_C_beg)), axis = 1)
data_voltage_end = np.concatenate((np.array(data_voltage_A_end),
                                  np.array(data_voltage_B_end),
                                  np.array(data_voltage_C_end)), axis = 1)
data_current_beg_ang = np.concatenate((np.array(data_current_A_beg_ang),
                                       np.array(data_current_B_beg_ang),
                                       np.array(data_current_C_beg_ang)), axis = 1)
data_current_end_ang = np.concatenate((np.array(data_current_A_end_ang),
                                       np.array(data_current_B_end_ang),
                                       np.array(data_current_C_end_ang)), axis = 1)
data_voltage_beg_ang = np.concatenate((np.array(data_voltage_A_beg_ang),
                                       np.array(data_voltage_B_beg_ang),
                                       np.array(data_voltage_C_beg_ang)), axis = 1)
data_voltage_end_ang = np.concatenate((np.array(data_voltage_A_end_ang),
                                       np.array(data_voltage_B_end_ang),
                                       np.array(data_voltage_C_end_ang)), axis = 1)

# %%
data.append([exp_data[exp, key].reset_index(drop=True).values])

# %%
с = current_A_begin['exp 1']

# %%
best_method = di(';', 'best_method.csv').main_process()

# %%
exp_names = pd.Series(best_method.columns)
feature_names = pd.Series(voltage_C_end.columns)[:3000]
exp_data = pd.DataFrame()

for feature_name in feature_names:
    
    df = pd.DataFrame(
    {
        'time': time['Time'],
        'current A beg': current_A_begin[feature_name],
        'current A end': current_A_end[feature_name],
        'current B beg': current_B_begin[feature_name],
        'current B end': current_B_end[feature_name],
        'current C beg': current_C_begin[feature_name],
        'current C end': current_C_end[feature_name],
        'current A angle begin': current_A_angle_begin[feature_name],
        'current_A_angle_end': current_A_angle_end[feature_name],
        'current_B_angle_begin': current_B_angle_begin[feature_name],
        'current_B_angle_end': current_B_angle_end[feature_name],
        'current_C_angle_begin': current_C_angle_begin[feature_name],
        'current_C_angle_end': current_C_angle_end[feature_name],
        'voltage_A_begin': voltage_A_begin[feature_name],
        'voltage_A_end': voltage_A_end[feature_name],
        'voltage_B_begin': voltage_B_begin[feature_name],
        'voltage_B_end': voltage_B_end[feature_name],
        'voltage_C_begin': voltage_C_begin[feature_name],
        'voltage_C_end': voltage_C_end[feature_name],
        'voltage_A_angle_begin': voltage_A_angle_begin[feature_name],
        'voltage_A_angle_end': voltage_A_angle_end[feature_name],
        'voltage_B_angle_begin': voltage_B_angle_begin[feature_name],
        'voltage_B_angle_end': voltage_B_angle_end[feature_name],
        'voltage_C_angle_begin': voltage_C_angle_begin[feature_name],
        'voltage_C_angle_end': voltage_C_angle_end[feature_name]
    }
    )
    df = df.set_index('time')
    df = df.transpose()

    names = pd.DataFrame({ 'Exp Num': []})
    for i in range(len(df)):
        name = pd.DataFrame({
            'Exp Num': pd.Series([feature_name], index=[i])
            })
        names = pd.concat([names, name], ignore_index=True)
    names.index = df.index
    
    df = pd.concat([df, names], axis=1)
    df = df.set_index(['Exp Num', df.index])

    exp_data = pd.concat([exp_data, df], axis = 0)

# %%
exp_data

# %%
exp_data.to_csv('exp_data.csv')

# %%
from alg_repository.data_importer import DataImporter as di

exp_data = di(',', 'exp_data.csv').main_process()
exp_data = exp_data.rename(columns={'Unnamed: 1': 'Name of meas'})
exp_data = exp_data.set_index(['Exp Num', 'Name of meas'])
exp_data = exp_data.transpose()

# %%
exp_data = exp_data.rename(columns={'Unnamed: 1': 'Name of meas'})

# %%
exp_data = exp_data.set_index(['Exp Num', 'Name of meas'])

# %%
exp_data = exp_data.transpose()

# %%
exp_data

# %%
del exp_data

# %%
columns_names = list(exp_data.columns)

print(columns_names[7][1].split('_'))

# %%
from alg_repository.data_importer import DataImporter as di
data = di('\t').main_process()

# %%
del data_end, data_end

# %%
import numpy as np

lib_meas = [
    'current',
    'voltage'
]

lib_phase = [
    'A',
    'B',
    'C'
]

lib_place = [
    'beg',
    'begin',
    'end'
]

for meas in lib_meas:
    for phase in lib_phase:
        for place in lib_place:
            data = []        
            for exp, key in exp_data.columns:
                if meas in key.split() or meas in key.split('_'):
                    if 'angle' not in key.split() or 'angle' not in key.split('_'): 
                        if phase in key.split('_') or phase in key.split():
                            if place in key.split('_') or place in key.split():
                                data.append([
                                    exp_data[exp, key].reset_index(drop=True).values
                                ])
                if phase == 'A':
                    if place == 'beg' or place == 'begin':
                        if meas == 'current':
                            data_cur_beg_A = np.array(data)
                        elif meas == 'voltage':
                            data_vol_beg_A = np.array(data)
                    elif place == 'end':
                        if meas == 'current':
                            data_cur_end_A = np.array(data)
                        elif meas == 'voltage':
                            data_vol_end_A = np.array(data)
                elif phase == 'B':
                    if place == 'beg' or place == 'begin':
                        if meas == 'current':
                            data_cur_beg_B = np.array(data)
                            try:
                                data_cur_beg = np.concatenate((data_cur_beg_A, data_cur_beg_B), axis=1)
                            except:
                                pass
                        elif meas == 'voltage':
                            data_vol_beg_B = np.array(data)
                            try:
                                data_vol_beg = np.concatenate((data_vol_beg_A, data_vol_beg_B), axis=1)
                            except:
                                pass
                    elif place == 'end':
                        if meas == 'current':
                            data_cur_end_B = np.array(data)
                            try:
                                data_cur_end = np.concatenate((data_cur_end_A, data_cur_end_B), axis=1)
                            except:
                                pass
                        elif meas == 'voltage':
                            data_vol_end_B = np.array(data)
                            try:
                                data_vol_end = np.concatenate((data_vol_end_A, data_vol_end_B), axis=1)
                            except:
                                pass
                elif phase == 'C':
                    if place == 'beg' or place == 'begin':
                        if meas == 'current':
                            data_cur_beg_C = np.array(data)
                            try:
                                data_cur_beg = np.concatenate((data_cur_beg_A, data_cur_beg_B, data_cur_beg_C), axis=1)
                            except:
                                pass
                        elif meas == 'voltage':
                            data_vol_beg_C = np.array(data)
                            try:
                                data_vol_beg = np.concatenate((data_vol_beg_A, data_vol_beg_B, data_vol_beg_C), axis=1)
                            except:
                                pass
                    elif place == 'end':
                        if meas == 'current':
                            data_cur_end_C = np.array(data)
                            try:
                                data_cur_end = np.concatenate((data_cur_end_A, data_cur_end_B, data_cur_end_C), axis=1)
                            except:
                                pass
                        elif meas == 'voltage':
                            data_vol_end_C = np.array(data)
                            try:
                                data_vol_end = np.concatenate((data_vol_end_A, data_vol_end_B, data_vol_end_C), axis=1)
                            except:
                                pass
            data = [] 
            for exp, key in exp_data.columns:
                if meas in key.split() or meas in key.split('_'):
                    if 'angle' in key.split() or 'angle' in key.split('_'): 
                        if phase in key.split('_') or phase in key.split():
                            if place in key.split('_') or place in key.split():
                                data.append([
                                    exp_data[exp, key].reset_index(drop=True).values
                                ]) 
                if phase == 'A' and meas == 'cuurent':
                    if place == 'beg' or place == 'begin':
                        data_cur_beg_ang_A = np.array(data)
                    elif place == 'end':
                        data_cur_end_ang_A = np.array(data)
                elif phase == 'B' and meas == 'cuurent':
                    if place == 'beg' or place == 'begin':
                        data_cur_beg_ang_B = np.array(data)
                        try:
                            data_cur_beg_ang = np.concatenate((data_cur_beg_ang_A, data_cur_beg_ang_B), axis=1)
                        except:
                            pass
                    elif place == 'end':
                        data_cur_end_ang_B = np.array(data)
                        try:
                            data_cur_end_ang = np.concatenate((data_cur_end_ang_A, data_cur_end_ang_B), axis=1)
                        except:
                            pass
                elif phase == 'C' and meas == 'cuurent':
                    if place == 'beg' or place == 'begin':
                        data_cur_beg_ang_C = np.array(data)
                        try:
                            data_cur_beg_ang = np.concatenate((data_cur_beg_ang_A, 
                                                               data_cur_beg_ang_B, data_cur_beg_ang_C), axis=1)
                        except:
                            pass
                    elif place == 'end':
                        data_cur_end_ang_C = np.array(data)
                        try:
                            data_cur_end_ang = np.concatenate((data_cur_end_ang_A, 
                                                               data_cur_end_ang_B, data_cur_end_ang_C), axis=1)
                        except:
                            pass
                elif phase == 'A' and meas == 'voltage':
                    if place == 'beg' or place == 'begin':
                        data_vol_beg_ang_A = np.array(data)
                    elif place == 'end':
                        data_vol_end_ang_A = np.array(data)
                elif phase == 'B' and meas == 'voltage':
                    if place == 'beg' or place == 'begin':
                        data_vol_beg_ang_B = np.array(data)
                        try:
                            data_vol_beg_ang = np.concatenate((data_vol_beg_ang_A, data_vol_beg_ang_B), axis=1)
                        except:
                            pass
                    elif place == 'end':
                        data_vol_end_ang_B = np.array(data)
                        try:
                            data_vol_end_ang = np.concatenate((data_vol_end_ang_A, data_vol_end_ang_B), axis=1)
                        except:
                            pass
                elif phase == 'C' and meas == 'voltage':
                    if place == 'beg' or place == 'begin':
                        data_vol_beg_ang_C = np.array(data)
                        try:
                            data_vol_beg_ang = np.concatenate((data_vol_beg_ang_A, 
                                                               data_vol_beg_ang_B, data_vol_beg_ang_C), axis=1)
                        except:
                            pass
                    elif place == 'end':
                        data_vol_end_ang_C = np.array(data)
                        try:
                            data_vol_end_ang = np.concatenate((data_vol_end_ang_A, 
                                                               data_vol_end_ang_B, data_vol_end_ang_C), axis=1)
                        except:
                            pass

# %%
del data_current_A

# %%
print(exp_data.columns)

# %%
from alg_repository.TSC_forest_model import TimeSeriesClassifierForest as tsc
import numpy as np
base_estimator=None,
n_estimators=200,
n_intervals="sqrt",
min_interval_length=3,
max_interval_length=np.inf,
time_limit_in_minutes=None,
contract_max_n_estimators=500,
random_state=None,
n_jobs=1,
parallel_backend= "multiprocessin"

config = {
     'base_estimator': base_estimator,
     'n_estimators': n_estimators,
     'n_intervals': n_intervals,
     'min_interval_length': min_interval_length,
     'max_interval_length': max_interval_length,
     'time_limit_in_minutes': time_limit_in_minutes,
     'contract_max_n_estimators': contract_max_n_estimators,
     'random_state': random_state,
     'n_jobs': n_jobs,
     'parallel_backend': parallel_backend
}
config['n_jobs'][0]

# %%
X = np.array([
    1,2,3,4,5
])
Y = np.array([
    1,2,3,4,5
])
model = tsc(config, X, Y)

data = model.data_preprocess()

print(data.X_train, ' ', data.Y_train, ' ', data.X_test, ' ', data.Y_test)

# %%
import numpy as np
from main import LearnProcess as lp
ml = lp('current begin')

X = ml.trainData()
Y = ml.aimData()

# %%
print(Y.flatten())

# %%
from main import LearnProcess as lp

model_1, acc, report = lp('current begin').fit()
# Out:
# Training the model:  current begin
# Accuracy: 0.325
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        24
#            2       0.10      0.06      0.08        66
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00        15
#            5       0.00      0.00      0.00        29
#            6       0.23      0.20      0.21       126
#            7       0.00      0.00      0.00         4
#            9       0.00      0.00      0.00         8
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         2
#           17       0.00      0.00      0.00        33
#           18       0.38      0.69      0.49       240
#
#     accuracy                           0.33       600
#    macro avg       0.05      0.07      0.06       600
# weighted avg       0.21      0.33      0.25       600
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from main import LearnProcess as lp

model_1, acc, report = lp('current begin', 'hydra').fit()
# Out:
# Training the model:  current begin
# Accuracy: 0.4
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        24
#            2       0.00      0.00      0.00        66
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00        15
#            5       0.00      0.00      0.00        29
#            6       0.00      0.00      0.00       126
#            7       0.00      0.00      0.00         4
#            9       0.00      0.00      0.00         8
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         2
#           17       0.00      0.00      0.00        33
#           18       0.40      1.00      0.57       240
#
#     accuracy                           0.40       600
#    macro avg       0.03      0.07      0.04       600
# weighted avg       0.16      0.40      0.23       600

# %%
from main import LearnProcess as lp
text = lp().FullExpProcess()
print(text)

# %%
import matplotlib.pyplot as plt
from alg_repository.data_importer import DataImporter as di
data = di().main_process()
ax1 = plt.plot(data)

# %%
model_2 = lp('current end').fit()
model_3 = lp('voltage begin').fit()
model_4 = lp('voltage end').fit()

# %%
model_5 = lp('current begin angle').fit()
model_6 = lp('current end angle').fit()
model_7 = lp('voltage begin angle').fit()
model_8 = lp('voltage end angle').fit()

# %%
from alg_repository.TSC_forest_model import TimeSeriesClassifierForest as tsc

de = tsc(config, X, Y)

data = de.data_preprocess()

# %%
from alg_repository.data_importer import DataImporter as di

y = di().main_process()

# %%
import numpy as np
import pandas as pd


def symifactor():
    
    alfa = np.exp(1j * 2 * np.pi/3)
    sym_factor = np.array([
        [1, 1, 1],
        [1, alfa**2, alfa],
        [1, alfa, alfa**2]
    ])
    return sym_factor

# %%
from main import LearnProcess as lp

data = lp()._preprocessing()

# %%
phase_vectors = np.array([
    data.current_A_begin['exp 1'][0]*np.exp(1j*data.current_A_angle_begin['exp 1'][0]),
    data.current_B_begin['exp 1'][0]*np.exp(1j*data.current_B_angle_begin['exp 1'][0]),
    data.current_C_begin['exp 1'][0]*np.exp(1j*data.current_C_angle_begin['exp 1'][0])
    ])
sym_comp = 1/3 * np.transpose(phase_vectors.transpose().dot(sym_factor()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       1 phase_vectors = np.array([
#       2     data.current_A_begin['exp 1'][0]*np.exp(1j*data.current_A_angle_begin['exp 1'][0]),
#       3     data.current_B_begin['exp 1'][0]*np.exp(1j*data.current_B_angle_begin['exp 1'][0]),
#       4     data.current_C_begin['exp 1'][0]*np.exp(1j*data.current_C_angle_begin['exp 1'][0])
#       5     ])
# ----> 6 sym_comp = 1/3 * np.transpose(phase_vectors.transpose().dot(sym_factor()))
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
t = data.current_C_begin

# %%
sym_factor = symifactor()

current_zero_seq_begin = pd.DataFrame()
current_zero_seq_angle_begin = pd.DataFrame()
current_negative_seq_begin = pd.DataFrame()
current_negative_seq_angle_begin = pd.DataFrame()
current_positive_seq_begin = pd.DataFrame()
current_positive_seq_angle_begin = pd.DataFrame()

# %%
for exp in data.current_A_angle_begin.columns.values:
    zero_seq_begin = []
    zero_seq_angle_begin = []
    negative_seq_begin = []
    negative_seq_angle_begin = []
    positive_seq_begin = []
    positive_seq_angle_begin = []

    for idx in range(len(data.current_A_angle_begin[exp])):
        phase_vectors = np.array([
        data.current_A_begin[exp][idx]*np.exp(1j*data.current_A_angle_begin[exp][idx]),
        data.current_B_begin[exp][idx]*np.exp(1j*data.current_B_angle_begin[exp][idx]),
        data.current_C_begin[exp][idx]*np.exp(1j*data.current_C_angle_begin[exp][idx])
        ])
        sym_comp = 1/3 * np.transpose(phase_vectors.transpose().dot(sym_factor))
        zero_seq_begin.append([np.abs(sym_comp[0])]) 
        zero_seq_angle_begin.append([np.angle(sym_comp[0])])
        negative_seq_begin.append([np.abs(sym_comp[1])])
        negative_seq_angle_begin.append([np.angle(sym_comp[1])])
        positive_seq_begin.append([np.abs(sym_comp[2])])
        positive_seq_angle_begin.append([np.angle(sym_comp[2])])
    
    current_zero_seq_begin[exp] = pd.DataFrame(zero_seq_begin)
    current_zero_seq_angle_begin[exp] = pd.DataFrame(zero_seq_angle_begin)
    current_negative_seq_begin[exp] = pd.DataFrame(negative_seq_begin)
    current_negative_seq_angle_begin[exp] = pd.DataFrame(negative_seq_angle_begin)
    current_positive_seq_begin[exp] = pd.DataFrame(positive_seq_begin)
    current_positive_seq_angle_begin[exp] = pd.DataFrame(positive_seq_angle_begin)

# %%
from alg_repository.PMU_symmetrical_components import PMU_symmetrical_components as pmu_sc
magnitude_A, magnitude_B, magnitude_C, angle_A, angle_B, angle_C = data.current_A_begin, data.current_B_begin, data.current_C_begin, data.current_A_angle_begin, data.current_B_angle_begin, data.current_C_angle_begin

seq = pmu_sc(magnitude_A, magnitude_B, magnitude_C, angle_A, angle_B, angle_C).vectors_calculation(['exp 1'], 0)

# %%
t = vars(data)
t.keys()
# Out:
# dict_keys(['current_A_begin', 'current_B_begin', 'current_C_begin', 'current_A_angle_begin', 'current_A_angle_end', 'current_B_angle_begin', 'current_B_angle_end', 'current_C_angle_begin', 'current_C_angle_end', 'current_A_end', 'current_B_end', 'current_C_end', 'voltage_A_angle_begin', 'voltage_A_angle_end', 'voltage_B_angle_begin', 'voltage_B_angle_end', 'voltage_C_angle_begin', 'voltage_C_angle_end', 'voltage_A_begin', 'voltage_A_end', 'voltage_B_begin', 'voltage_B_end', 'voltage_C_begin', 'voltage_C_end', 'exp_library', 'exp_type', 'fit_type', 'fit_library', 'time', 'data_current_beg', 'data_current_end', 'data_voltage_beg', 'data_voltage_end', 'data_current_beg_ang', 'data_current_end_ang', 'data_voltage_beg_ang', 'data_voltage_end_ang'])

# %%
t = seq[2]

# %%
import matplotlib.pyplot as plt

plt.plot(t)
# Out:
# [<matplotlib.lines.Line2D at 0x1ca3cffff80>,
#  <matplotlib.lines.Line2D at 0x1ca3df7bad0>,
#  <matplotlib.lines.Line2D at 0x1ca3f21aea0>,
#  <matplotlib.lines.Line2D at 0x1ca42c0ef00>,
#  <matplotlib.lines.Line2D at 0x1ca3f21b8f0>,
#  <matplotlib.lines.Line2D at 0x1ca3f21b830>,
#  <matplotlib.lines.Line2D at 0x1ca3f2191f0>,
#  <matplotlib.lines.Line2D at 0x1ca3f21bb30>,
#  <matplotlib.lines.Line2D at 0x1ca3f21a7b0>,
#  <matplotlib.lines.Line2D at 0x1ca3f219760>,
#  <matplotlib.lines.Line2D at 0x1ca40996360>,
#  <matplotlib.lines.Line2D at 0x1ca3f21b530>,
#  <matplotlib.lines.Line2D at 0x1ca42b740b0>,
#  <matplotlib.lines.Line2D at 0x1ca42c0f230>,
#  <matplotlib.lines.Line2D at 0x1ca42c0f260>,
#  <matplotlib.lines.Line2D at 0x1ca42b74e30>,
#  <matplotlib.lines.Line2D at 0x1ca42b770b0>,
#  <matplotlib.lines.Line2D at 0x1ca42b74fb0>,
#  <matplotlib.lines.Line2D at 0x1ca3f218e30>,
#  <matplotlib.lines.Line2D at 0x1ca3f160b60>,
#  <matplotlib.lines.Line2D at 0x1ca3f160e00>,
#  <matplotlib.lines.Line2D at 0x1ca42b8eff0>,
#  <matplotlib.lines.Line2D at 0x1ca42b8ca40>,
#  <matplotlib.lines.Line2D at 0x1ca42b8d970>,
#  <matplotlib.lines.Line2D at 0x1ca42b8d730>,
#  <matplotlib.lines.Line2D at 0x1ca42b8d370>,
#  <matplotlib.lines.Line2D at 0x1ca42b8cda0>,
#  <matplotlib.lines.Line2D at 0x1ca42b8f8f0>,
#  <matplotlib.lines.Line2D at 0x1ca3f8dbf20>,
#  <matplotlib.lines.Line2D at 0x1ca3f2062a0>,
#  <matplotlib.lines.Line2D at 0x1ca3f204c80>,
#  <matplotlib.lines.Line2D at 0x1ca3f2047a0>,
#  <matplotlib.lines.Line2D at 0x1ca3f814170>,
#  <matplotlib.lines.Line2D at 0x1ca3f1e5820>,
#  <matplotlib.lines.Line2D at 0x1ca3f1e74a0>,
#  <matplotlib.lines.Line2D at 0x1ca3f1e71a0>,
#  <matplotlib.lines.Line2D at 0x1ca42c0c440>,
#  <matplotlib.lines.Line2D at 0x1ca3f1e7b60>,
#  <matplotlib.lines.Line2D at 0x1ca3f1e64e0>,
#  <matplotlib.lines.Line2D at 0x1ca3f1e4c80>,
#  <matplotlib.lines.Line2D at 0x1ca3f1e5430>,
#  <matplotlib.lines.Line2D at 0x1ca42bdf470>,
#  <matplotlib.lines.Line2D at 0x1ca42bdf680>,
#  <matplotlib.lines.Line2D at 0x1ca42bdf9e0>,
#  <matplotlib.lines.Line2D at 0x1ca42bdfad0>,
#  <matplotlib.lines.Line2D at 0x1ca42bdfbc0>,
#  <matplotlib.lines.Line2D at 0x1ca42bdfcb0>,
#  <matplotlib.lines.Line2D at 0x1ca42bdfd70>,
#  <matplotlib.lines.Line2D at 0x1ca42bdfe60>,
#  <matplotlib.lines.Line2D at 0x1ca42bdff50>,
#  <matplotlib.lines.Line2D at 0x1ca42b55e20>,
#  <matplotlib.lines.Line2D at 0x1ca3f1f51c0>,
#  <matplotlib.lines.Line2D at 0x1ca3f1f6d20>,
#  <matplotlib.lines.Line2D at 0x1ca3f1f4740>,
#  <matplotlib.lines.Line2D at 0x1ca3f1f66c0>,
#  <matplotlib.lines.Line2D at 0x1ca3f1f7500>,
#  <matplotlib.lines.Line2D at 0x1ca42b326f0>,
#  <matplotlib.lines.Line2D at 0x1ca42b31640>,
#  <matplotlib.lines.Line2D at 0x1ca42b30680>,
#  <matplotlib.lines.Line2D at 0x1ca42b30a70>,
#  <matplotlib.lines.Line2D at 0x1ca42b314c0>,
#  <matplotlib.lines.Line2D at 0x1ca42b321b0>,
#  <matplotlib.lines.Line2D at 0x1ca3f0dc380>,
#  <matplotlib.lines.Line2D at 0x1ca3f0dc590>,
#  <matplotlib.lines.Line2D at 0x1ca3f0dc680>,
#  <matplotlib.lines.Line2D at 0x1ca3f1e46b0>,
#  <matplotlib.lines.Line2D at 0x1ca3f0dd190>,
#  <matplotlib.lines.Line2D at 0x1ca3f0dd5e0>,
#  <matplotlib.lines.Line2D at 0x1ca3f0dd100>,
#  <matplotlib.lines.Line2D at 0x1ca3f0dd340>,
#  <matplotlib.lines.Line2D at 0x1ca3f0dcd10>,
#  <matplotlib.lines.Line2D at 0x1ca3f194140>,
#  <matplotlib.lines.Line2D at 0x1ca3f1952b0>,
#  <matplotlib.lines.Line2D at 0x1ca3f197b30>,
#  <matplotlib.lines.Line2D at 0x1ca3f1421b0>,
#  <matplotlib.lines.Line2D at 0x1ca4098a630>,
#  <matplotlib.lines.Line2D at 0x1ca409892e0>,
#  <matplotlib.lines.Line2D at 0x1ca4098bc20>,
#  <matplotlib.lines.Line2D at 0x1ca4098b5c0>,
#  <matplotlib.lines.Line2D at 0x1ca42c14110>,
#  <matplotlib.lines.Line2D at 0x1ca42b764b0>,
#  <matplotlib.lines.Line2D at 0x1ca42c141d0>,
#  <matplotlib.lines.Line2D at 0x1ca42c14380>,
#  <matplotlib.lines.Line2D at 0x1ca42c14470>,
#  <matplotlib.lines.Line2D at 0x1ca42c14560>,
#  <matplotlib.lines.Line2D at 0x1ca42c14650>,
#  <matplotlib.lines.Line2D at 0x1ca42c14740>,
#  <matplotlib.lines.Line2D at 0x1ca42c14830>,
#  <matplotlib.lines.Line2D at 0x1ca42c14920>,
#  <matplotlib.lines.Line2D at 0x1ca42c14a10>,
#  <matplotlib.lines.Line2D at 0x1ca42c14b00>,
#  <matplotlib.lines.Line2D at 0x1ca42c14bf0>,
#  <matplotlib.lines.Line2D at 0x1ca42c14ce0>,
#  <matplotlib.lines.Line2D at 0x1ca42c14da0>,
#  <matplotlib.lines.Line2D at 0x1ca42c0c380>,
#  <matplotlib.lines.Line2D at 0x1ca3f0e8a70>,
#  <matplotlib.lines.Line2D at 0x1ca42c14e90>,
#  <matplotlib.lines.Line2D at 0x1ca42c15100>,
#  <matplotlib.lines.Line2D at 0x1ca42c151f0>,
#  <matplotlib.lines.Line2D at 0x1ca42c152e0>,
#  <matplotlib.lines.Line2D at 0x1ca42c153d0>,
#  <matplotlib.lines.Line2D at 0x1ca42c154c0>,
#  <matplotlib.lines.Line2D at 0x1ca42c155b0>,
#  <matplotlib.lines.Line2D at 0x1ca42c156a0>,
#  <matplotlib.lines.Line2D at 0x1ca42c15790>,
#  <matplotlib.lines.Line2D at 0x1ca42c15850>,
#  <matplotlib.lines.Line2D at 0x1ca42c15910>,
#  <matplotlib.lines.Line2D at 0x1ca42c159d0>,
#  <matplotlib.lines.Line2D at 0x1ca42b761b0>,
#  <matplotlib.lines.Line2D at 0x1ca42c15ac0>,
#  <matplotlib.lines.Line2D at 0x1ca42c15c70>,
#  <matplotlib.lines.Line2D at 0x1ca3f17d2e0>,
#  <matplotlib.lines.Line2D at 0x1ca42c0ffb0>,
#  <matplotlib.lines.Line2D at 0x1ca3f17d5e0>,
#  <matplotlib.lines.Line2D at 0x1ca3f21a330>,
#  <matplotlib.lines.Line2D at 0x1ca42c15d60>,
#  <matplotlib.lines.Line2D at 0x1ca42c16120>,
#  <matplotlib.lines.Line2D at 0x1ca42c16210>,
#  <matplotlib.lines.Line2D at 0x1ca42c16300>,
#  <matplotlib.lines.Line2D at 0x1ca42c163f0>,
#  <matplotlib.lines.Line2D at 0x1ca42c164e0>,
#  <matplotlib.lines.Line2D at 0x1ca42c165d0>,
#  <matplotlib.lines.Line2D at 0x1ca42c166c0>,
#  <matplotlib.lines.Line2D at 0x1ca42c167b0>,
#  <matplotlib.lines.Line2D at 0x1ca42c168a0>,
#  <matplotlib.lines.Line2D at 0x1ca42c16960>,
#  <matplotlib.lines.Line2D at 0x1ca42c16a50>,
#  <matplotlib.lines.Line2D at 0x1ca42c16b40>,
#  <matplotlib.lines.Line2D at 0x1ca42c16c30>,
#  <matplotlib.lines.Line2D at 0x1ca42c16d20>,
#  <matplotlib.lines.Line2D at 0x1ca42c16de0>,
#  <matplotlib.lines.Line2D at 0x1ca42c16ed0>,
#  <matplotlib.lines.Line2D at 0x1ca42c16fc0>,
#  <matplotlib.lines.Line2D at 0x1ca42c170b0>,
#  <matplotlib.lines.Line2D at 0x1ca42c171a0>,
#  <matplotlib.lines.Line2D at 0x1ca409caff0>,
#  <matplotlib.lines.Line2D at 0x1ca42c17290>,
#  <matplotlib.lines.Line2D at 0x1ca42c17410>,
#  <matplotlib.lines.Line2D at 0x1ca42c17500>,
#  <matplotlib.lines.Line2D at 0x1ca42c175f0>,
#  <matplotlib.lines.Line2D at 0x1ca42c176e0>,
#  <matplotlib.lines.Line2D at 0x1ca42c177d0>,
#  <matplotlib.lines.Line2D at 0x1ca42c178c0>,
#  <matplotlib.lines.Line2D at 0x1ca42c179b0>,
#  <matplotlib.lines.Line2D at 0x1ca42c17aa0>,
#  <matplotlib.lines.Line2D at 0x1ca42c17b90>,
#  <matplotlib.lines.Line2D at 0x1ca42c17c80>,
#  <matplotlib.lines.Line2D at 0x1ca42c17d70>,
#  <matplotlib.lines.Line2D at 0x1ca42c17e60>,
#  <matplotlib.lines.Line2D at 0x1ca42c17f20>,
#  <matplotlib.lines.Line2D at 0x1ca409fc050>,
#  <matplotlib.lines.Line2D at 0x1ca409fc140>,
#  <matplotlib.lines.Line2D at 0x1ca409fc230>,
#  <matplotlib.lines.Line2D at 0x1ca409fc320>,
#  <matplotlib.lines.Line2D at 0x1ca409fc410>,
#  <matplotlib.lines.Line2D at 0x1ca409fc500>,
#  <matplotlib.lines.Line2D at 0x1ca409fc5f0>,
#  <matplotlib.lines.Line2D at 0x1ca409fc6e0>,
#  <matplotlib.lines.Line2D at 0x1ca409fc7d0>,
#  <matplotlib.lines.Line2D at 0x1ca409fc8c0>,
#  <matplotlib.lines.Line2D at 0x1ca409fc9b0>,
#  <matplotlib.lines.Line2D at 0x1ca409fcaa0>,
#  <matplotlib.lines.Line2D at 0x1ca409fcb90>,
#  <matplotlib.lines.Line2D at 0x1ca42b31eb0>,
#  <matplotlib.lines.Line2D at 0x1ca409fcc80>,
#  <matplotlib.lines.Line2D at 0x1ca409fce30>,
#  <matplotlib.lines.Line2D at 0x1ca409fcf20>,
#  <matplotlib.lines.Line2D at 0x1ca42c0c800>,
#  <matplotlib.lines.Line2D at 0x1ca409fd010>,
#  <matplotlib.lines.Line2D at 0x1ca409fd1c0>,
#  <matplotlib.lines.Line2D at 0x1ca409fd2b0>,
#  <matplotlib.lines.Line2D at 0x1ca409fd3a0>,
#  <matplotlib.lines.Line2D at 0x1ca409fd490>,
#  <matplotlib.lines.Line2D at 0x1ca409fd580>,
#  <matplotlib.lines.Line2D at 0x1ca409fd670>,
#  <matplotlib.lines.Line2D at 0x1ca3f0dc650>,
#  <matplotlib.lines.Line2D at 0x1ca409fd760>,
#  <matplotlib.lines.Line2D at 0x1ca409fd910>,
#  <matplotlib.lines.Line2D at 0x1ca409fda00>,
#  <matplotlib.lines.Line2D at 0x1ca409fdaf0>,
#  <matplotlib.lines.Line2D at 0x1ca40a00920>,
#  <matplotlib.lines.Line2D at 0x1ca40a00a10>,
#  <matplotlib.lines.Line2D at 0x1ca3f91d6a0>,
#  <matplotlib.lines.Line2D at 0x1ca40a00b00>,
#  <matplotlib.lines.Line2D at 0x1ca40a00cb0>,
#  <matplotlib.lines.Line2D at 0x1ca40a00da0>,
#  <matplotlib.lines.Line2D at 0x1ca40a00e90>,
#  <matplotlib.lines.Line2D at 0x1ca40a00f80>,
#  <matplotlib.lines.Line2D at 0x1ca40a01070>,
#  <matplotlib.lines.Line2D at 0x1ca40a01160>,
#  <matplotlib.lines.Line2D at 0x1ca40a01250>,
#  <matplotlib.lines.Line2D at 0x1ca40a01340>,
#  <matplotlib.lines.Line2D at 0x1ca40a01430>,
#  <matplotlib.lines.Line2D at 0x1ca40a01520>,
#  <matplotlib.lines.Line2D at 0x1ca40a01610>,
#  <matplotlib.lines.Line2D at 0x1ca3d733920>,
#  <matplotlib.lines.Line2D at 0x1ca40a01700>,
#  <matplotlib.lines.Line2D at 0x1ca40a018b0>,
#  <matplotlib.lines.Line2D at 0x1ca40a019a0>,
#  <matplotlib.lines.Line2D at 0x1ca40a01a90>,
#  <matplotlib.lines.Line2D at 0x1ca40a01b80>,
#  <matplotlib.lines.Line2D at 0x1ca40a01c70>,
#  <matplotlib.lines.Line2D at 0x1ca40a01d60>,
#  <matplotlib.lines.Line2D at 0x1ca40a01e50>,
#  <matplotlib.lines.Line2D at 0x1ca40a01f40>,
#  <matplotlib.lines.Line2D at 0x1ca40a02030>,
#  <matplotlib.lines.Line2D at 0x1ca42b769f0>,
#  <matplotlib.lines.Line2D at 0x1ca40a02120>,
#  <matplotlib.lines.Line2D at 0x1ca40a022d0>,
#  <matplotlib.lines.Line2D at 0x1ca40a023c0>,
#  <matplotlib.lines.Line2D at 0x1ca40a024b0>,
#  <matplotlib.lines.Line2D at 0x1ca40a025a0>,
#  <matplotlib.lines.Line2D at 0x1ca40a02690>,
#  <matplotlib.lines.Line2D at 0x1ca40a02780>,
#  <matplotlib.lines.Line2D at 0x1ca40a02870>,
#  <matplotlib.lines.Line2D at 0x1ca40a02960>,
#  <matplotlib.lines.Line2D at 0x1ca40a02a50>,
#  <matplotlib.lines.Line2D at 0x1ca40a02b40>,
#  <matplotlib.lines.Line2D at 0x1ca40a02c30>,
#  <matplotlib.lines.Line2D at 0x1ca40a02d20>,
#  <matplotlib.lines.Line2D at 0x1ca40a02e10>,
#  <matplotlib.lines.Line2D at 0x1ca40a02f00>,
#  <matplotlib.lines.Line2D at 0x1ca40a02ff0>,
#  <matplotlib.lines.Line2D at 0x1ca40a030e0>,
#  <matplotlib.lines.Line2D at 0x1ca40a031d0>,
#  <matplotlib.lines.Line2D at 0x1ca40a032c0>,
#  <matplotlib.lines.Line2D at 0x1ca40a033b0>,
#  <matplotlib.lines.Line2D at 0x1ca40a034a0>,
#  <matplotlib.lines.Line2D at 0x1ca40a03590>,
#  <matplotlib.lines.Line2D at 0x1ca40a03680>,
#  <matplotlib.lines.Line2D at 0x1ca40a03770>,
#  <matplotlib.lines.Line2D at 0x1ca40a03860>,
#  <matplotlib.lines.Line2D at 0x1ca40a03950>,
#  <matplotlib.lines.Line2D at 0x1ca40a03a40>,
#  <matplotlib.lines.Line2D at 0x1ca42c0f5c0>,
#  <matplotlib.lines.Line2D at 0x1ca40a03b30>,
#  <matplotlib.lines.Line2D at 0x1ca40a03ce0>,
#  <matplotlib.lines.Line2D at 0x1ca40a03dd0>,
#  <matplotlib.lines.Line2D at 0x1ca40a03ec0>,
#  <matplotlib.lines.Line2D at 0x1ca40a03fb0>,
#  <matplotlib.lines.Line2D at 0x1ca40a600e0>,
#  <matplotlib.lines.Line2D at 0x1ca40a601d0>,
#  <matplotlib.lines.Line2D at 0x1ca40a602c0>,
#  <matplotlib.lines.Line2D at 0x1ca40a603b0>,
#  <matplotlib.lines.Line2D at 0x1ca40a604a0>,
#  <matplotlib.lines.Line2D at 0x1ca40a60590>,
#  <matplotlib.lines.Line2D at 0x1ca40a60680>,
#  <matplotlib.lines.Line2D at 0x1ca40a60770>,
#  <matplotlib.lines.Line2D at 0x1ca40a60860>,
#  <matplotlib.lines.Line2D at 0x1ca40a60950>,
#  <matplotlib.lines.Line2D at 0x1ca40a60a40>,
#  <matplotlib.lines.Line2D at 0x1ca40a60b30>,
#  <matplotlib.lines.Line2D at 0x1ca40a60c20>,
#  <matplotlib.lines.Line2D at 0x1ca40a60d10>,
#  <matplotlib.lines.Line2D at 0x1ca40a60e00>,
#  <matplotlib.lines.Line2D at 0x1ca42b8eab0>,
#  <matplotlib.lines.Line2D at 0x1ca40a60ef0>,
#  <matplotlib.lines.Line2D at 0x1ca40a610a0>,
#  <matplotlib.lines.Line2D at 0x1ca40a61190>,
#  <matplotlib.lines.Line2D at 0x1ca40a61280>,
#  <matplotlib.lines.Line2D at 0x1ca40a61370>,
#  <matplotlib.lines.Line2D at 0x1ca40a61460>,
#  <matplotlib.lines.Line2D at 0x1ca3cffe7e0>,
#  <matplotlib.lines.Line2D at 0x1ca40a61550>,
#  <matplotlib.lines.Line2D at 0x1ca40a61700>,
#  <matplotlib.lines.Line2D at 0x1ca40a617f0>,
#  <matplotlib.lines.Line2D at 0x1ca40a618e0>,
#  <matplotlib.lines.Line2D at 0x1ca40a619d0>,
#  <matplotlib.lines.Line2D at 0x1ca40a61ac0>,
#  <matplotlib.lines.Line2D at 0x1ca40a61bb0>,
#  <matplotlib.lines.Line2D at 0x1ca40a61ca0>,
#  <matplotlib.lines.Line2D at 0x1ca40a61d90>,
#  <matplotlib.lines.Line2D at 0x1ca40a61e80>,
#  <matplotlib.lines.Line2D at 0x1ca40a61f70>,
#  <matplotlib.lines.Line2D at 0x1ca40a62060>,
#  <matplotlib.lines.Line2D at 0x1ca40a62150>,
#  <matplotlib.lines.Line2D at 0x1ca40a62240>,
#  <matplotlib.lines.Line2D at 0x1ca40a62330>,
#  <matplotlib.lines.Line2D at 0x1ca40a62420>,
#  <matplotlib.lines.Line2D at 0x1ca40a62510>,
#  <matplotlib.lines.Line2D at 0x1ca40a62600>,
#  <matplotlib.lines.Line2D at 0x1ca40a626f0>,
#  <matplotlib.lines.Line2D at 0x1ca40a627e0>,
#  <matplotlib.lines.Line2D at 0x1ca40a628d0>,
#  <matplotlib.lines.Line2D at 0x1ca40a629c0>,
#  <matplotlib.lines.Line2D at 0x1ca40a62ab0>,
#  <matplotlib.lines.Line2D at 0x1ca40a62ba0>,
#  <matplotlib.lines.Line2D at 0x1ca40a62c90>,
#  <matplotlib.lines.Line2D at 0x1ca40a62d80>,
#  <matplotlib.lines.Line2D at 0x1ca40a62e70>,
#  <matplotlib.lines.Line2D at 0x1ca40a62f60>,
#  <matplotlib.lines.Line2D at 0x1ca40a63050>,
#  <matplotlib.lines.Line2D at 0x1ca40a63140>,
#  <matplotlib.lines.Line2D at 0x1ca40a63230>,
#  <matplotlib.lines.Line2D at 0x1ca40a63320>,
#  <matplotlib.lines.Line2D at 0x1ca40a63410>,
#  <matplotlib.lines.Line2D at 0x1ca40a63500>,
#  <matplotlib.lines.Line2D at 0x1ca40a635f0>,
#  <matplotlib.lines.Line2D at 0x1ca40a636e0>,
#  <matplotlib.lines.Line2D at 0x1ca40a637d0>,
#  <matplotlib.lines.Line2D at 0x1ca40a638c0>,
#  <matplotlib.lines.Line2D at 0x1ca40a639b0>,
#  <matplotlib.lines.Line2D at 0x1ca40a63aa0>,
#  <matplotlib.lines.Line2D at 0x1ca40a63b90>,
#  <matplotlib.lines.Line2D at 0x1ca40a63c80>,
#  <matplotlib.lines.Line2D at 0x1ca40a63d70>,
#  <matplotlib.lines.Line2D at 0x1ca40a63e60>,
#  <matplotlib.lines.Line2D at 0x1ca40a63f50>,
#  <matplotlib.lines.Line2D at 0x1ca40a74080>,
#  <matplotlib.lines.Line2D at 0x1ca40a74170>,
#  <matplotlib.lines.Line2D at 0x1ca40a74260>,
#  <matplotlib.lines.Line2D at 0x1ca40a74350>,
#  <matplotlib.lines.Line2D at 0x1ca40a74440>,
#  <matplotlib.lines.Line2D at 0x1ca40a74530>,
#  <matplotlib.lines.Line2D at 0x1ca40a74620>,
#  <matplotlib.lines.Line2D at 0x1ca40a74710>,
#  <matplotlib.lines.Line2D at 0x1ca40a74800>,
#  <matplotlib.lines.Line2D at 0x1ca40a748f0>,
#  <matplotlib.lines.Line2D at 0x1ca40a749e0>,
#  <matplotlib.lines.Line2D at 0x1ca40a74ad0>,
#  <matplotlib.lines.Line2D at 0x1ca40a74bc0>,
#  <matplotlib.lines.Line2D at 0x1ca40a74cb0>,
#  <matplotlib.lines.Line2D at 0x1ca40a74da0>,
#  <matplotlib.lines.Line2D at 0x1ca40a74e90>,
#  <matplotlib.lines.Line2D at 0x1ca40a74f80>,
#  <matplotlib.lines.Line2D at 0x1ca40a75070>,
#  <matplotlib.lines.Line2D at 0x1ca40a75160>,
#  <matplotlib.lines.Line2D at 0x1ca40a75250>,
#  <matplotlib.lines.Line2D at 0x1ca40a75340>,
#  <matplotlib.lines.Line2D at 0x1ca40a75430>,
#  <matplotlib.lines.Line2D at 0x1ca40a75520>,
#  <matplotlib.lines.Line2D at 0x1ca40a75610>,
#  <matplotlib.lines.Line2D at 0x1ca40a75700>,
#  <matplotlib.lines.Line2D at 0x1ca40a757f0>,
#  <matplotlib.lines.Line2D at 0x1ca40a758e0>,
#  <matplotlib.lines.Line2D at 0x1ca40a759d0>,
#  <matplotlib.lines.Line2D at 0x1ca40a75ac0>,
#  <matplotlib.lines.Line2D at 0x1ca40a75bb0>,
#  <matplotlib.lines.Line2D at 0x1ca3f961370>,
#  <matplotlib.lines.Line2D at 0x1ca40a75ca0>,
#  <matplotlib.lines.Line2D at 0x1ca40a75e50>,
#  <matplotlib.lines.Line2D at 0x1ca40a75f40>,
#  <matplotlib.lines.Line2D at 0x1ca40a76030>,
#  <matplotlib.lines.Line2D at 0x1ca40a76120>,
#  <matplotlib.lines.Line2D at 0x1ca40a76210>,
#  <matplotlib.lines.Line2D at 0x1ca40a76300>,
#  <matplotlib.lines.Line2D at 0x1ca40a763f0>,
#  <matplotlib.lines.Line2D at 0x1ca40a764e0>,
#  <matplotlib.lines.Line2D at 0x1ca3f21b9b0>,
#  <matplotlib.lines.Line2D at 0x1ca40a765d0>,
#  <matplotlib.lines.Line2D at 0x1ca40a76780>,
#  <matplotlib.lines.Line2D at 0x1ca40a76870>,
#  <matplotlib.lines.Line2D at 0x1ca40a76960>,
#  <matplotlib.lines.Line2D at 0x1ca40a76a50>,
#  <matplotlib.lines.Line2D at 0x1ca40a76b40>,
#  <matplotlib.lines.Line2D at 0x1ca40a76c30>,
#  <matplotlib.lines.Line2D at 0x1ca40a76d20>,
#  <matplotlib.lines.Line2D at 0x1ca40a76e10>,
#  <matplotlib.lines.Line2D at 0x1ca40a76f00>,
#  <matplotlib.lines.Line2D at 0x1ca3f17dd30>,
#  <matplotlib.lines.Line2D at 0x1ca40a76ff0>,
#  <matplotlib.lines.Line2D at 0x1ca40a771a0>,
#  <matplotlib.lines.Line2D at 0x1ca40a77290>,
#  <matplotlib.lines.Line2D at 0x1ca40a77380>,
#  <matplotlib.lines.Line2D at 0x1ca40a77470>,
#  <matplotlib.lines.Line2D at 0x1ca40a77560>,
#  <matplotlib.lines.Line2D at 0x1ca3df7b560>,
#  <matplotlib.lines.Line2D at 0x1ca40a77650>,
#  <matplotlib.lines.Line2D at 0x1ca40a77800>,
#  <matplotlib.lines.Line2D at 0x1ca40a778f0>,
#  <matplotlib.lines.Line2D at 0x1ca40a779e0>,
#  <matplotlib.lines.Line2D at 0x1ca40a77ad0>,
#  <matplotlib.lines.Line2D at 0x1ca40a77bc0>,
#  <matplotlib.lines.Line2D at 0x1ca40a77cb0>,
#  <matplotlib.lines.Line2D at 0x1ca40a77da0>,
#  <matplotlib.lines.Line2D at 0x1ca40a77e90>,
#  <matplotlib.lines.Line2D at 0x1ca40a77f80>,
#  <matplotlib.lines.Line2D at 0x1ca40a900b0>,
#  <matplotlib.lines.Line2D at 0x1ca40a901a0>,
#  <matplotlib.lines.Line2D at 0x1ca40a90290>,
#  <matplotlib.lines.Line2D at 0x1ca40a90380>,
#  <matplotlib.lines.Line2D at 0x1ca40a90470>,
#  <matplotlib.lines.Line2D at 0x1ca42b760f0>,
#  <matplotlib.lines.Line2D at 0x1ca40a90560>,
#  <matplotlib.lines.Line2D at 0x1ca40a90710>,
#  <matplotlib.lines.Line2D at 0x1ca40a90800>,
#  <matplotlib.lines.Line2D at 0x1ca40a908f0>,
#  <matplotlib.lines.Line2D at 0x1ca40a909e0>,
#  <matplotlib.lines.Line2D at 0x1ca40a90ad0>,
#  <matplotlib.lines.Line2D at 0x1ca40a90bc0>,
#  <matplotlib.lines.Line2D at 0x1ca40a90cb0>,
#  <matplotlib.lines.Line2D at 0x1ca40a90da0>,
#  <matplotlib.lines.Line2D at 0x1ca40a90e90>,
#  <matplotlib.lines.Line2D at 0x1ca40a90f80>,
#  <matplotlib.lines.Line2D at 0x1ca40a91070>,
#  <matplotlib.lines.Line2D at 0x1ca40a91160>,
#  <matplotlib.lines.Line2D at 0x1ca40a91250>,
#  <matplotlib.lines.Line2D at 0x1ca40a91340>,
#  <matplotlib.lines.Line2D at 0x1ca40a91430>,
#  <matplotlib.lines.Line2D at 0x1ca40a91520>,
#  <matplotlib.lines.Line2D at 0x1ca40a91610>,
#  <matplotlib.lines.Line2D at 0x1ca40a91700>,
#  <matplotlib.lines.Line2D at 0x1ca40a917f0>,
#  <matplotlib.lines.Line2D at 0x1ca40a918e0>,
#  <matplotlib.lines.Line2D at 0x1ca40a919d0>,
#  <matplotlib.lines.Line2D at 0x1ca42b763f0>,
#  <matplotlib.lines.Line2D at 0x1ca40a91ac0>,
#  <matplotlib.lines.Line2D at 0x1ca40a91c70>,
#  <matplotlib.lines.Line2D at 0x1ca40a91d60>,
#  <matplotlib.lines.Line2D at 0x1ca40a91e50>,
#  <matplotlib.lines.Line2D at 0x1ca40a91f40>,
#  <matplotlib.lines.Line2D at 0x1ca40a92030>,
#  <matplotlib.lines.Line2D at 0x1ca40a92120>,
#  <matplotlib.lines.Line2D at 0x1ca40a92210>,
#  <matplotlib.lines.Line2D at 0x1ca40a92300>,
#  <matplotlib.lines.Line2D at 0x1ca40a923f0>,
#  <matplotlib.lines.Line2D at 0x1ca40a924e0>,
#  <matplotlib.lines.Line2D at 0x1ca40a925d0>,
#  <matplotlib.lines.Line2D at 0x1ca40a926c0>,
#  <matplotlib.lines.Line2D at 0x1ca40a927b0>,
#  <matplotlib.lines.Line2D at 0x1ca40a928a0>,
#  <matplotlib.lines.Line2D at 0x1ca40a92990>,
#  <matplotlib.lines.Line2D at 0x1ca40a92a80>,
#  <matplotlib.lines.Line2D at 0x1ca40a92b70>,
#  <matplotlib.lines.Line2D at 0x1ca42b8f230>,
#  <matplotlib.lines.Line2D at 0x1ca40a92c60>,
#  <matplotlib.lines.Line2D at 0x1ca40a92e10>,
#  <matplotlib.lines.Line2D at 0x1ca40a92f00>,
#  <matplotlib.lines.Line2D at 0x1ca40a92ff0>,
#  <matplotlib.lines.Line2D at 0x1ca40a930e0>,
#  <matplotlib.lines.Line2D at 0x1ca40a931d0>,
#  <matplotlib.lines.Line2D at 0x1ca40a932c0>,
#  <matplotlib.lines.Line2D at 0x1ca40a933b0>,
#  <matplotlib.lines.Line2D at 0x1ca40a934a0>,
#  <matplotlib.lines.Line2D at 0x1ca409b17f0>,
#  <matplotlib.lines.Line2D at 0x1ca40a93590>,
#  <matplotlib.lines.Line2D at 0x1ca40a93740>,
#  <matplotlib.lines.Line2D at 0x1ca40a93830>,
#  <matplotlib.lines.Line2D at 0x1ca40a93920>,
#  <matplotlib.lines.Line2D at 0x1ca40a93a10>,
#  <matplotlib.lines.Line2D at 0x1ca40a93b00>,
#  <matplotlib.lines.Line2D at 0x1ca40a93bf0>,
#  <matplotlib.lines.Line2D at 0x1ca40a93ce0>,
#  <matplotlib.lines.Line2D at 0x1ca40a93dd0>,
#  <matplotlib.lines.Line2D at 0x1ca40a93ec0>,
#  <matplotlib.lines.Line2D at 0x1ca40a93fb0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa80e0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa81d0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa82c0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa83b0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa84a0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa8590>,
#  <matplotlib.lines.Line2D at 0x1ca40aa8680>,
#  <matplotlib.lines.Line2D at 0x1ca40aa8770>,
#  <matplotlib.lines.Line2D at 0x1ca40aa8860>,
#  <matplotlib.lines.Line2D at 0x1ca40aa8950>,
#  <matplotlib.lines.Line2D at 0x1ca40aa8a40>,
#  <matplotlib.lines.Line2D at 0x1ca40aa8b30>,
#  <matplotlib.lines.Line2D at 0x1ca40aa8c20>,
#  <matplotlib.lines.Line2D at 0x1ca40aa8d10>,
#  <matplotlib.lines.Line2D at 0x1ca40aa8e00>,
#  <matplotlib.lines.Line2D at 0x1ca40aa8ef0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa8fe0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa90d0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa91c0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa92b0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa93a0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa9490>,
#  <matplotlib.lines.Line2D at 0x1ca40aa9580>,
#  <matplotlib.lines.Line2D at 0x1ca40aa9670>,
#  <matplotlib.lines.Line2D at 0x1ca42b8fbf0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa9760>,
#  <matplotlib.lines.Line2D at 0x1ca40aa9910>,
#  <matplotlib.lines.Line2D at 0x1ca40aa9a00>,
#  <matplotlib.lines.Line2D at 0x1ca40aa9af0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa9be0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa9cd0>,
#  <matplotlib.lines.Line2D at 0x1ca42b8e930>,
#  <matplotlib.lines.Line2D at 0x1ca40aa9dc0>,
#  <matplotlib.lines.Line2D at 0x1ca40aa9f70>,
#  <matplotlib.lines.Line2D at 0x1ca40aaa060>,
#  <matplotlib.lines.Line2D at 0x1ca40aaa150>,
#  <matplotlib.lines.Line2D at 0x1ca40aaa240>,
#  <matplotlib.lines.Line2D at 0x1ca40aaa330>,
#  <matplotlib.lines.Line2D at 0x1ca40aaa420>,
#  <matplotlib.lines.Line2D at 0x1ca40aaa510>,
#  <matplotlib.lines.Line2D at 0x1ca40aaa600>,
#  <matplotlib.lines.Line2D at 0x1ca40aaa6f0>,
#  <matplotlib.lines.Line2D at 0x1ca40aaa7e0>,
#  <matplotlib.lines.Line2D at 0x1ca40aaa8d0>,
#  <matplotlib.lines.Line2D at 0x1ca40aaa9c0>,
#  <matplotlib.lines.Line2D at 0x1ca40aaaab0>,
#  <matplotlib.lines.Line2D at 0x1ca40aaaba0>,
#  <matplotlib.lines.Line2D at 0x1ca40aaac90>,
#  <matplotlib.lines.Line2D at 0x1ca40aaad80>,
#  <matplotlib.lines.Line2D at 0x1ca40aaae70>,
#  <matplotlib.lines.Line2D at 0x1ca40aaaf60>,
#  <matplotlib.lines.Line2D at 0x1ca40aab050>,
#  <matplotlib.lines.Line2D at 0x1ca40aab140>,
#  <matplotlib.lines.Line2D at 0x1ca40aab230>,
#  <matplotlib.lines.Line2D at 0x1ca40aab320>,
#  <matplotlib.lines.Line2D at 0x1ca40aab410>,
#  <matplotlib.lines.Line2D at 0x1ca40aab500>,
#  <matplotlib.lines.Line2D at 0x1ca40aab5f0>,
#  <matplotlib.lines.Line2D at 0x1ca40aab6e0>,
#  <matplotlib.lines.Line2D at 0x1ca40aab7d0>,
#  <matplotlib.lines.Line2D at 0x1ca40aab8c0>,
#  <matplotlib.lines.Line2D at 0x1ca40aab9b0>,
#  <matplotlib.lines.Line2D at 0x1ca40aabaa0>,
#  <matplotlib.lines.Line2D at 0x1ca40aabb90>,
#  <matplotlib.lines.Line2D at 0x1ca40aabc80>,
#  <matplotlib.lines.Line2D at 0x1ca40aabd70>,
#  <matplotlib.lines.Line2D at 0x1ca40aabe60>,
#  <matplotlib.lines.Line2D at 0x1ca40aabf50>,
#  <matplotlib.lines.Line2D at 0x1ca40acc080>,
#  <matplotlib.lines.Line2D at 0x1ca40acc170>,
#  <matplotlib.lines.Line2D at 0x1ca40acc260>,
#  <matplotlib.lines.Line2D at 0x1ca40acc350>,
#  <matplotlib.lines.Line2D at 0x1ca40acc440>,
#  <matplotlib.lines.Line2D at 0x1ca40acc530>,
#  <matplotlib.lines.Line2D at 0x1ca40acc620>,
#  <matplotlib.lines.Line2D at 0x1ca40acc710>,
#  <matplotlib.lines.Line2D at 0x1ca40acc800>,
#  <matplotlib.lines.Line2D at 0x1ca42b8f3b0>,
#  <matplotlib.lines.Line2D at 0x1ca40acc8f0>,
#  <matplotlib.lines.Line2D at 0x1ca40accaa0>,
#  <matplotlib.lines.Line2D at 0x1ca40accb90>,
#  <matplotlib.lines.Line2D at 0x1ca409b16a0>,
#  <matplotlib.lines.Line2D at 0x1ca40accc80>,
#  <matplotlib.lines.Line2D at 0x1ca40acce30>,
#  <matplotlib.lines.Line2D at 0x1ca40accf20>,
#  <matplotlib.lines.Line2D at 0x1ca40acd010>,
#  <matplotlib.lines.Line2D at 0x1ca40acd100>,
#  <matplotlib.lines.Line2D at 0x1ca40acd1f0>,
#  <matplotlib.lines.Line2D at 0x1ca3f105970>,
#  <matplotlib.lines.Line2D at 0x1ca3f1e4080>,
#  <matplotlib.lines.Line2D at 0x1ca40acd2e0>,
#  <matplotlib.lines.Line2D at 0x1ca40acd550>,
#  <matplotlib.lines.Line2D at 0x1ca40acd640>,
#  <matplotlib.lines.Line2D at 0x1ca40acd730>,
#  <matplotlib.lines.Line2D at 0x1ca40acd820>,
#  <matplotlib.lines.Line2D at 0x1ca40acd910>,
#  <matplotlib.lines.Line2D at 0x1ca40acda00>,
#  <matplotlib.lines.Line2D at 0x1ca40acdaf0>,
#  <matplotlib.lines.Line2D at 0x1ca40acdbe0>,
#  <matplotlib.lines.Line2D at 0x1ca40acdcd0>,
#  <matplotlib.lines.Line2D at 0x1ca40acddc0>,
#  <matplotlib.lines.Line2D at 0x1ca40acdeb0>,
#  <matplotlib.lines.Line2D at 0x1ca40acdfa0>,
#  <matplotlib.lines.Line2D at 0x1ca3f0dc890>,
#  <matplotlib.lines.Line2D at 0x1ca40ace090>,
>,
#  <matplotlib.lines.Line2D at 0x1ca4f2da090>,
#  <matplotlib.lines.Line2D at 0x1ca4f2da180>,
#  <matplotlib.lines.Line2D at 0x1ca4f2da270>,
#  <matplotlib.lines.Line2D at 0x1ca4f2da360>,
#  <matplotlib.lines.Line2D at 0x1ca4f2da450>,
#  <matplotlib.lines.Line2D at 0x1ca4f2da540>,
#  <matplotlib.lines.Line2D at 0x1ca4f2da630>,
#  <matplotlib.lines.Line2D at 0x1ca4f2da720>,
#  <matplotlib.lines.Line2D at 0x1ca4f2da810>,
#  <matplotlib.lines.Line2D at 0x1ca4f2da900>,
#  <matplotlib.lines.Line2D at 0x1ca4f2da9f0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2daae0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2dabd0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2dacc0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2dadb0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2daea0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2daf90>,
#  <matplotlib.lines.Line2D at 0x1ca4f2db080>,
#  <matplotlib.lines.Line2D at 0x1ca4f2db170>,
#  <matplotlib.lines.Line2D at 0x1ca4f2db260>,
#  <matplotlib.lines.Line2D at 0x1ca4f2db350>,
#  <matplotlib.lines.Line2D at 0x1ca4f2db440>,
#  <matplotlib.lines.Line2D at 0x1ca4f2db530>,
#  <matplotlib.lines.Line2D at 0x1ca4f2db620>,
#  <matplotlib.lines.Line2D at 0x1ca4f2db710>,
#  <matplotlib.lines.Line2D at 0x1ca4f2db800>,
#  <matplotlib.lines.Line2D at 0x1ca4f2db8f0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2db9e0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2dbad0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2dbbc0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2dbcb0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2dbda0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2dbe90>,
#  <matplotlib.lines.Line2D at 0x1ca4f2dbf80>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f80b0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f81a0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8290>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8380>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8470>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8560>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8650>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8740>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8830>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8920>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8a10>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8b00>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8bf0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8ce0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8dd0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8ec0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f8fb0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f90a0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9190>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9280>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9370>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9460>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9550>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9640>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9730>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9820>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9910>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9a00>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9af0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9be0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9cd0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9dc0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9eb0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2f9fa0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fa090>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fa180>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fa270>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fa360>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fa450>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fa540>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fa630>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fa720>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fa810>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fa900>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fa9f0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2faae0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fabd0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2facc0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fadb0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2faea0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2faf90>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fb080>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fb170>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fb260>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fb350>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fb440>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fb530>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fb620>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fb710>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fb800>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fb8f0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fb9e0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fbad0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fbbc0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fbcb0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fbda0>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fbe90>,
#  <matplotlib.lines.Line2D at 0x1ca4f2fbf80>,
#  <matplotlib.lines.Line2D at 0x1ca4f3100b0>,
#  <matplotlib.lines.Line2D at 0x1ca4f3101a0>,
#  <matplotlib.lines.Line2D at 0x1ca4f310290>,
#  <matplotlib.lines.Line2D at 0x1ca4f310380>,
#  <matplotlib.lines.Line2D at 0x1ca4f310470>,
#  <matplotlib.lines.Line2D at 0x1ca4f310560>,
#  <matplotlib.lines.Line2D at 0x1ca4f310650>,
#  <matplotlib.lines.Line2D at 0x1ca4f310740>,
#  <matplotlib.lines.Line2D at 0x1ca4f310830>,
#  <matplotlib.lines.Line2D at 0x1ca4f310920>,
#  <matplotlib.lines.Line2D at 0x1ca4f310a10>,
#  <matplotlib.lines.Line2D at 0x1ca4f310b00>,
#  <matplotlib.lines.Line2D at 0x1ca4f310bf0>,
#  <matplotlib.lines.Line2D at 0x1ca4f310ce0>,
#  <matplotlib.lines.Line2D at 0x1ca4f310dd0>,
#  <matplotlib.lines.Line2D at 0x1ca4f310ec0>,
#  <matplotlib.lines.Line2D at 0x1ca4f310fb0>,
#  <matplotlib.lines.Line2D at 0x1ca4f3110a0>,
#  <matplotlib.lines.Line2D at 0x1ca4f311190>,
#  <matplotlib.lines.Line2D at 0x1ca4f311280>,
#  <matplotlib.lines.Line2D at 0x1ca4f311370>,
#  <matplotlib.lines.Line2D at 0x1ca4f311460>,
#  <matplotlib.lines.Line2D at 0x1ca4f311550>,
#  <matplotlib.lines.Line2D at 0x1ca4f311640>,
#  <matplotlib.lines.Line2D at 0x1ca4f311730>,
#  <matplotlib.lines.Line2D at 0x1ca4f311820>,
#  <matplotlib.lines.Line2D at 0x1ca4f311910>,
#  <matplotlib.lines.Line2D at 0x1ca4f311a00>,
#  <matplotlib.lines.Line2D at 0x1ca4f311af0>,
#  <matplotlib.lines.Line2D at 0x1ca4f311be0>,
#  <matplotlib.lines.Line2D at 0x1ca4f311cd0>,
#  <matplotlib.lines.Line2D at 0x1ca4f311dc0>,
#  <matplotlib.lines.Line2D at 0x1ca4f311eb0>,
#  <matplotlib.lines.Line2D at 0x1ca4f311fa0>,
#  <matplotlib.lines.Line2D at 0x1ca4f312090>,
#  <matplotlib.lines.Line2D at 0x1ca4f312180>,
#  <matplotlib.lines.Line2D at 0x1ca4f312270>,
#  <matplotlib.lines.Line2D at 0x1ca4f312360>,
#  <matplotlib.lines.Line2D at 0x1ca4f312450>,
#  <matplotlib.lines.Line2D at 0x1ca4f312540>,
#  <matplotlib.lines.Line2D at 0x1ca4f312630>,
#  <matplotlib.lines.Line2D at 0x1ca4f312720>,
#  <matplotlib.lines.Line2D at 0x1ca4f312810>,
#  <matplotlib.lines.Line2D at 0x1ca4f312900>,
#  <matplotlib.lines.Line2D at 0x1ca4f3129f0>,
#  <matplotlib.lines.Line2D at 0x1ca4f312ae0>,
#  <matplotlib.lines.Line2D at 0x1ca4f312bd0>,
#  <matplotlib.lines.Line2D at 0x1ca4f312cc0>,
#  <matplotlib.lines.Line2D at 0x1ca4f312db0>,
#  <matplotlib.lines.Line2D at 0x1ca4f312ea0>,
#  <matplotlib.lines.Line2D at 0x1ca4f312f90>,
#  <matplotlib.lines.Line2D at 0x1ca4f313080>,
#  <matplotlib.lines.Line2D at 0x1ca4f313170>,
#  <matplotlib.lines.Line2D at 0x1ca4f313260>,
#  <matplotlib.lines.Line2D at 0x1ca4f313350>,
#  <matplotlib.lines.Line2D at 0x1ca4f313440>,
#  <matplotlib.lines.Line2D at 0x1ca4f313530>,
#  <matplotlib.lines.Line2D at 0x1ca4f313620>,
#  <matplotlib.lines.Line2D at 0x1ca4f313710>,
#  <matplotlib.lines.Line2D at 0x1ca4f313800>,
#  <matplotlib.lines.Line2D at 0x1ca4f3138f0>,
#  <matplotlib.lines.Line2D at 0x1ca4f3139e0>,
#  <matplotlib.lines.Line2D at 0x1ca4f313ad0>,
#  <matplotlib.lines.Line2D at 0x1ca4f313bc0>,
#  <matplotlib.lines.Line2D at 0x1ca4f313cb0>,
#  <matplotlib.lines.Line2D at 0x1ca4f313da0>,
#  <matplotlib.lines.Line2D at 0x1ca4f313e90>,
#  <matplotlib.lines.Line2D at 0x1ca4f313f80>,
#  <matplotlib.lines.Line2D at 0x1ca4f3280b0>,
#  <matplotlib.lines.Line2D at 0x1ca4f3281a0>,
#  <matplotlib.lines.Line2D at 0x1ca4f328290>,
#  <matplotlib.lines.Line2D at 0x1ca4f328380>,
#  <matplotlib.lines.Line2D at 0x1ca4f328470>,
#  <matplotlib.lines.Line2D at 0x1ca4f328560>,
#  <matplotlib.lines.Line2D at 0x1ca4f328650>,
#  <matplotlib.lines.Line2D at 0x1ca4f328740>,
#  <matplotlib.lines.Line2D at 0x1ca4f328830>,
#  <matplotlib.lines.Line2D at 0x1ca4f328920>,
#  <matplotlib.lines.Line2D at 0x1ca4f328a10>,
#  <matplotlib.lines.Line2D at 0x1ca4f328b00>,
#  <matplotlib.lines.Line2D at 0x1ca4f328bf0>,
#  <matplotlib.lines.Line2D at 0x1ca4f328ce0>,
#  <matplotlib.lines.Line2D at 0x1ca4f328dd0>,
#  <matplotlib.lines.Line2D at 0x1ca4f328ec0>,
#  <matplotlib.lines.Line2D at 0x1ca4f328fb0>,
#  <matplotlib.lines.Line2D at 0x1ca4f3290a0>,
#  <matplotlib.lines.Line2D at 0x1ca4f329190>,
#  <matplotlib.lines.Line2D at 0x1ca4f329280>,
#  <matplotlib.lines.Line2D at 0x1ca4f329370>,
#  <matplotlib.lines.Line2D at 0x1ca4f329460>,
#  <matplotlib.lines.Line2D at 0x1ca4f329550>,
#  <matplotlib.lines.Line2D at 0x1ca4f329640>,
#  <matplotlib.lines.Line2D at 0x1ca4f329730>,
#  <matplotlib.lines.Line2D at 0x1ca4f329820>,
#  <matplotlib.lines.Line2D at 0x1ca4f329910>,
#  <matplotlib.lines.Line2D at 0x1ca4f329a00>,
#  <matplotlib.lines.Line2D at 0x1ca4f329af0>,
#  <matplotlib.lines.Line2D at 0x1ca4f329be0>,
#  <matplotlib.lines.Line2D at 0x1ca4f329cd0>,
#  <matplotlib.lines.Line2D at 0x1ca4f329dc0>,
#  <matplotlib.lines.Line2D at 0x1ca4f329eb0>,
#  <matplotlib.lines.Line2D at 0x1ca4f329fa0>,
#  <matplotlib.lines.Line2D at 0x1ca4f32a090>,
#  <matplotlib.lines.Line2D at 0x1ca4f32a180>,
#  <matplotlib.lines.Line2D at 0x1ca4f32a270>,
#  <matplotlib.lines.Line2D at 0x1ca4f32a360>,
#  <matplotlib.lines.Line2D at 0x1ca4f32a450>,
#  <matplotlib.lines.Line2D at 0x1ca4f32a540>,
#  <matplotlib.lines.Line2D at 0x1ca4f32a630>,
#  <matplotlib.lines.Line2D at 0x1ca4f32a720>,
#  <matplotlib.lines.Line2D at 0x1ca4f32a810>,
#  <matplotlib.lines.Line2D at 0x1ca4f32a900>,
#  <matplotlib.lines.Line2D at 0x1ca4f32a9f0>,
#  <matplotlib.lines.Line2D at 0x1ca4f32aae0>,
#  <matplotlib.lines.Line2D at 0x1ca4f32abd0>,
#  <matplotlib.lines.Line2D at 0x1ca4f32acc0>,
#  <matplotlib.lines.Line2D at 0x1ca4f32adb0>,
#  <matplotlib.lines.Line2D at 0x1ca4f32aea0>,
#  <matplotlib.lines.Line2D at 0x1ca4f32af90>,
#  <matplotlib.lines.Line2D at 0x1ca4f32b080>,
#  <matplotlib.lines.Line2D at 0x1ca4f32b170>,
#  <matplotlib.lines.Line2D at 0x1ca4f32b260>,
#  <matplotlib.lines.Line2D at 0x1ca4f32b350>,
#  <matplotlib.lines.Line2D at 0x1ca4f32b440>,
#  <matplotlib.lines.Line2D at 0x1ca4f32b530>,
#  <matplotlib.lines.Line2D at 0x1ca4f32b620>,
#  <matplotlib.lines.Line2D at 0x1ca4f32b710>,
#  <matplotlib.lines.Line2D at 0x1ca4f32b800>,
#  <matplotlib.lines.Line2D at 0x1ca4f32b8f0>,
#  <matplotlib.lines.Line2D at 0x1ca4f32b9e0>,
#  <matplotlib.lines.Line2D at 0x1ca4f32bad0>,
#  <matplotlib.lines.Line2D at 0x1ca4f32bbc0>,
#  <matplotlib.lines.Line2D at 0x1ca4f32bcb0>,
#  <matplotlib.lines.Line2D at 0x1ca4f32bda0>,
#  <matplotlib.lines.Line2D at 0x1ca4f32be90>,
#  <matplotlib.lines.Line2D at 0x1ca4f32bf80>,
#  <matplotlib.lines.Line2D at 0x1ca4f3480b0>,
#  <matplotlib.lines.Line2D at 0x1ca4f3481a0>,
#  <matplotlib.lines.Line2D at 0x1ca4f348290>,
#  <matplotlib.lines.Line2D at 0x1ca4f348380>,
#  <matplotlib.lines.Line2D at 0x1ca4f348470>,
#  <matplotlib.lines.Line2D at 0x1ca4f348560>,
#  <matplotlib.lines.Line2D at 0x1ca4f348650>,
#  <matplotlib.lines.Line2D at 0x1ca4f348740>,
#  <matplotlib.lines.Line2D at 0x1ca4f348830>,
#  <matplotlib.lines.Line2D at 0x1ca4f348920>,
#  <matplotlib.lines.Line2D at 0x1ca4f348a10>,
#  <matplotlib.lines.Line2D at 0x1ca4f348b00>,
#  <matplotlib.lines.Line2D at 0x1ca4f348bf0>,
#  <matplotlib.lines.Line2D at 0x1ca4f348ce0>,
#  <matplotlib.lines.Line2D at 0x1ca4f348dd0>,
#  <matplotlib.lines.Line2D at 0x1ca4f348ec0>,
#  <matplotlib.lines.Line2D at 0x1ca4f348fb0>,
#  <matplotlib.lines.Line2D at 0x1ca4f3490a0>,
#  <matplotlib.lines.Line2D at 0x1ca4f349190>,
#  <matplotlib.lines.Line2D at 0x1ca4f349280>,
#  <matplotlib.lines.Line2D at 0x1ca4f349370>,
#  <matplotlib.lines.Line2D at 0x1ca4f349460>,
#  <matplotlib.lines.Line2D at 0x1ca4f349550>,
#  <matplotlib.lines.Line2D at 0x1ca4f349640>,
#  <matplotlib.lines.Line2D at 0x1ca4f349730>,
#  <matplotlib.lines.Line2D at 0x1ca4f349820>,
#  <matplotlib.lines.Line2D at 0x1ca4f349910>,
#  ...]

# %%
file_mapping = {
    'current A begin': data.current_A_begin,
    'current A end': data.current_A_end,
    'current B begin': data.current_B_begin,
    'current B end': data.current_B_end,
    'current C begin': data.current_C_begin,
    'current C end': data.current_C_end,
    'voltage A begin': data.voltage_A_begin,
    'voltage A end': data.voltage_A_end,
    'voltage B begin': data.voltage_B_begin,
    'voltage B end': data.voltage_B_end,
    'voltage C begin': data.voltage_C_begin,
    'voltage C end': data.voltage_C_end,
    'current A angle begin': data.current_A_angle_begin,
    'current A angle end': data.current_A_angle_end,
    'current B angle begin': data.current_B_angle_begin,
    'current B angle end': data.current_B_angle_end,
    'current C angle begin': data.current_C_angle_begin,
    'current C angle end': data.current_C_angle_end,
    'voltage A angle begin': data.voltage_A_angle_begin,
    'voltage A angle end': data.voltage_A_angle_end,
    'voltage B angle begin': data.voltage_B_angle_begin,
    'voltage B angle end': data.voltage_B_angle_end,
    'voltage C angle begin': data.voltage_C_angle_begin,
    'voltage C angle end': data.voltage_C_angle_end
}

file_mapping['current A begin']['exp 1']
# Out:
# 0       2137.969451
# 1       2137.969451
# 8497  361.377709  907.458534  158.509680  375.858100  14.108326
# 8498  361.377709  907.458534  158.509680  375.858100  14.108326
# 8499  361.377709  907.458534  158.509680  375.858100  14.108326
#
# [8500 rows x 3062 columns]

# %%
current_zero_seq_begin = np.abs(sym_comp[0])
current_zero_seq_angle_begin = np.angle(sym_comp[0])
current_negative_seq_begin = np.abs(sym_comp[1])
current_negative_seq_angle_begin = np.angle(sym_comp[1])
current_positive_seq_begin = np.abs(sym_comp[2])
current_positive_seq_angle_begin = np.angle(sym_comp[2])

print("current_zero_seq_begin = ", current_zero_seq_begin)
print("current_zero_seq_angle_begin = ", current_zero_seq_angle_begin)
print("current_negative_seq_begin = ", current_negative_seq_begin)
print("current_negative_seq_angle_begin = ", current_negative_seq_angle_begin)
print("current_positive_seq_begin = ", current_positive_seq_begin)
print("current_positive_seq_angle_begin = ", current_positive_seq_angle_begin)
# Out:
# current_zero_seq_begin =  1.4384033912352285
# current_zero_seq_angle_begin =  -2.739901941548227
# current_negative_seq_begin =  5.920137272184155
# current_negative_seq_angle_begin =  -2.782349384501557
# current_positive_seq_begin =  2142.9501189252987
# current_positive_seq_angle_begin =  -0.4583800564631985

# %%
print(data.current_C_begin['exp 1'][0])
print(data.current_C_angle_begin['exp 1'][0])
# Out:
# 2148.24003
# 1.636019953

# %%
import matplotlib.pyplot as plt

plt.plot(current_negative_seq_begin)
# Out:
# [<matplotlib.lines.Line2D at 0x17c3d2c71a0>,
#  <matplotlib.lines.Line2D at 0x17c3d275c10>,
#  <matplotlib.lines.Line2D at 0x17c3d2b8e90>,
#  <matplotlib.lines.Line2D at 0x17c3d2ba9f0>,
#  <matplotlib.lines.Line2D at 0x17c3d2bbd40>,
#  <matplotlib.lines.Line2D at 0x17c3d2b8b00>,
#  <matplotlib.lines.Line2D at 0x17c3d2b9dc0>,
#  <matplotlib.lines.Line2D at 0x17c3d2b9670>,
#  <matplotlib.lines.Line2D at 0x17c3d2baed0>,
#  <matplotlib.lines.Line2D at 0x17c3d2ba750>,
#  <matplotlib.lines.Line2D at 0x17c3d2baa50>,
#  <matplotlib.lines.Line2D at 0x17c3d2b97f0>,
#  <matplotlib.lines.Line2D at 0x17c3d2ba4b0>,
#  <matplotlib.lines.Line2D at 0x17c3d2bb6b0>,
#  <matplotlib.lines.Line2D at 0x17c3d2ba5a0>,
#  <matplotlib.lines.Line2D at 0x17c3d2bb920>,
#  <matplotlib.lines.Line2D at 0x17c3d2bbbc0>,
#  <matplotlib.lines.Line2D at 0x17c3d2bafc0>,
#  <matplotlib.lines.Line2D at 0x17c3d2bbb60>,
#  <matplotlib.lines.Line2D at 0x17c3d2b9220>,
#  <matplotlib.lines.Line2D at 0x17c3d2b85c0>,
#  <matplotlib.lines.Line2D at 0x17c3d2bb380>,
#  <matplotlib.lines.Line2D at 0x17c3d2b8350>,
#  <matplotlib.lines.Line2D at 0x17c3d2bbb00>,
#  <matplotlib.lines.Line2D at 0x17c3d2b9910>,
#  <matplotlib.lines.Line2D at 0x17c3d2b82c0>,
#  <matplotlib.lines.Line2D at 0x17c3d2b8410>,
#  <matplotlib.lines.Line2D at 0x17c3d2bba70>,
#  <matplotlib.lines.Line2D at 0x17c3d2b8290>,
#  <matplotlib.lines.Line2D at 0x17c3d2bbf20>,
#  <matplotlib.lines.Line2D at 0x17c3d2ba0f0>,
#  <matplotlib.lines.Line2D at 0x17c3cd821e0>,
#  <matplotlib.lines.Line2D at 0x17c3cd82510>,
#  <matplotlib.lines.Line2D at 0x17c3cd80ce0>,
#  <matplotlib.lines.Line2D at 0x17c3cd83f80>,
#  <matplotlib.lines.Line2D at 0x17c3cd804a0>,
#  <matplotlib.lines.Line2D at 0x17c3cd813a0>,
#  <matplotlib.lines.Line2D at 0x17c3cd83950>,
#  <matplotlib.lines.Line2D at 0x17c3cd82f60>,
#  <matplotlib.lines.Line2D at 0x17c3cd803b0>,
#  <matplotlib.lines.Line2D at 0x17c3cd82e40>,
#  <matplotlib.lines.Line2D at 0x17c3cd830b0>,
#  <matplotlib.lines.Line2D at 0x17c3cd834d0>,
#  <matplotlib.lines.Line2D at 0x17c3cd83bc0>,
#  <matplotlib.lines.Line2D at 0x17c3cd80290>,
#  <matplotlib.lines.Line2D at 0x17c3cd83440>,
#  <matplotlib.lines.Line2D at 0x17c3cd80b00>,
#  <matplotlib.lines.Line2D at 0x17c3cd80c20>,
#  <matplotlib.lines.Line2D at 0x17c3cd80b60>,
#  <matplotlib.lines.Line2D at 0x17c3d2b9c70>,
#  <matplotlib.lines.Line2D at 0x17c3cd80140>,
#  <matplotlib.lines.Line2D at 0x17c3cd80620>,
#  <matplotlib.lines.Line2D at 0x17c3cd836b0>,
#  <matplotlib.lines.Line2D at 0x17c3cd83740>,
#  <matplotlib.lines.Line2D at 0x17c3cd81100>,
#  <matplotlib.lines.Line2D at 0x17c3cd80f80>,
#  <matplotlib.lines.Line2D at 0x17c3cd800b0>,
#  <matplotlib.lines.Line2D at 0x17c3cd80830>,
#  <matplotlib.lines.Line2D at 0x17c3cd80410>,
#  <matplotlib.lines.Line2D at 0x17c3cd80350>,
#  <matplotlib.lines.Line2D at 0x17c3cd83830>,
#  <matplotlib.lines.Line2D at 0x17c3cd839e0>,
#  <matplotlib.lines.Line2D at 0x17c3cd82ea0>,
#  <matplotlib.lines.Line2D at 0x17c3cd82990>,
#  <matplotlib.lines.Line2D at 0x17c3cd82210>,
#  <matplotlib.lines.Line2D at 0x17c3cd81490>,
#  <matplotlib.lines.Line2D at 0x17c3cd81250>,
#  <matplotlib.lines.Line2D at 0x17c3cd837a0>,
#  <matplotlib.lines.Line2D at 0x17c3cd812b0>,
#  <matplotlib.lines.Line2D at 0x17c3d2c66c0>,
#  <matplotlib.lines.Line2D at 0x17c3cd835c0>,
#  <matplotlib.lines.Line2D at 0x17c3cd82c00>,
#  <matplotlib.lines.Line2D at 0x17c3cd82b70>,
#  <matplotlib.lines.Line2D at 0x17c3d278fe0>,
#  <matplotlib.lines.Line2D at 0x17c3d279520>,
#  <matplotlib.lines.Line2D at 0x17c3d2780e0>,
#  <matplotlib.lines.Line2D at 0x17c3cb9f440>,
#  <matplotlib.lines.Line2D at 0x17c3cb9d640>,
#  <matplotlib.lines.Line2D at 0x17c3cb9f890>,
#  <matplotlib.lines.Line2D at 0x17c3cb9e420>,
#  <matplotlib.lines.Line2D at 0x17c3cb9e3c0>,
#  <matplotlib.lines.Line2D at 0x17c3cb9f290>,
#  <matplotlib.lines.Line2D at 0x17c3cb9e090>,
#  <matplotlib.lines.Line2D at 0x17c3cb9e660>,
#  <matplotlib.lines.Line2D at 0x17c3cb9e4b0>,
#  <matplotlib.lines.Line2D at 0x17c3cb9c560>,
#  <matplotlib.lines.Line2D at 0x17c3cb9ea50>,
#  <matplotlib.lines.Line2D at 0x17c3cb9e810>,
#  <matplotlib.lines.Line2D at 0x17c3cb9e900>,
#  <matplotlib.lines.Line2D at 0x17c3cb9f260>,
#  <matplotlib.lines.Line2D at 0x17c3cb9d370>,
#  <matplotlib.lines.Line2D at 0x17c3cb9dbb0>,
#  <matplotlib.lines.Line2D at 0x17c3cb9e540>,
#  <matplotlib.lines.Line2D at 0x17c3cb9eab0>,
#  <matplotlib.lines.Line2D at 0x17c3cb9deb0>,
#  <matplotlib.lines.Line2D at 0x17c3cb9c800>,
#  <matplotlib.lines.Line2D at 0x17c3cb94380>,
#  <matplotlib.lines.Line2D at 0x17c3cb95190>,
#  <matplotlib.lines.Line2D at 0x17c3cb950d0>,
#  <matplotlib.lines.Line2D at 0x17c3cb97860>,
#  <matplotlib.lines.Line2D at 0x17c3cb97a10>,
#  <matplotlib.lines.Line2D at 0x17c3cb97530>,
#  <matplotlib.lines.Line2D at 0x17c3cb970e0>,
#  <matplotlib.lines.Line2D at 0x179caf123f0>,
#  <matplotlib.lines.Line2D at 0x17c3cb725d0>,
#  <matplotlib.lines.Line2D at 0x17c3cb72120>,
#  <matplotlib.lines.Line2D at 0x17c3cb73d70>,
#  <matplotlib.lines.Line2D at 0x17c3cb73e60>,
#  <matplotlib.lines.Line2D at 0x17c3cb73aa0>,
#  <matplotlib.lines.Line2D at 0x17c3cb728a0>,
#  <matplotlib.lines.Line2D at 0x17c3cb72780>,
#  <matplotlib.lines.Line2D at 0x17c3cb73c50>,
#  <matplotlib.lines.Line2D at 0x17c3cb702f0>,
#  <matplotlib.lines.Line2D at 0x17c3cb70830>,
#  <matplotlib.lines.Line2D at 0x17c3cb710a0>,
#  <matplotlib.lines.Line2D at 0x17c3cb718b0>,
#  <matplotlib.lines.Line2D at 0x17c3cb70e90>,
#  <matplotlib.lines.Line2D at 0x17c3cb71280>,
#  <matplotlib.lines.Line2D at 0x17c3cda8c80>,
#  <matplotlib.lines.Line2D at 0x17c3d2c7a70>,
#  <matplotlib.lines.Line2D at 0x17c3cda8230>,
#  <matplotlib.lines.Line2D at 0x17c3cda9040>,
#  <matplotlib.lines.Line2D at 0x17c3cdab0b0>,
#  <matplotlib.lines.Line2D at 0x17c3cda9700>,
#  <matplotlib.lines.Line2D at 0x17c3cdabaa0>,
#  <matplotlib.lines.Line2D at 0x17c3d2304a0>,
#  <matplotlib.lines.Line2D at 0x17c3d230a10>,
#  <matplotlib.lines.Line2D at 0x17c3d2309b0>,
#  <matplotlib.lines.Line2D at 0x17c3d230920>,
#  <matplotlib.lines.Line2D at 0x17c3d230e90>,
#  <matplotlib.lines.Line2D at 0x17c3d231040>,
#  <matplotlib.lines.Line2D at 0x17c3d231370>,
#  <matplotlib.lines.Line2D at 0x17c3d2313a0>,
#  <matplotlib.lines.Line2D at 0x17c3d231190>,
#  <matplotlib.lines.Line2D at 0x17c3d230e00>,
#  <matplotlib.lines.Line2D at 0x17c3d2315e0>,
#  <matplotlib.lines.Line2D at 0x17c3d230050>,
#  <matplotlib.lines.Line2D at 0x17c3d231790>,
#  <matplotlib.lines.Line2D at 0x17c3d231a30>,
#  <matplotlib.lines.Line2D at 0x17c3d231a00>,
#  <matplotlib.lines.Line2D at 0x17c3d231970>,
#  <matplotlib.lines.Line2D at 0x17c3d231d30>,
#  <matplotlib.lines.Line2D at 0x17c3d231fd0>,
#  <matplotlib.lines.Line2D at 0x17c3d231fa0>,
#  <matplotlib.lines.Line2D at 0x17c3d231f10>,
#  <matplotlib.lines.Line2D at 0x17c3d232420>,
#  <matplotlib.lines.Line2D at 0x17c3d232810>,
#  <matplotlib.lines.Line2D at 0x17c3d2327b0>,
#  <matplotlib.lines.Line2D at 0x17c3d232720>,
#  <matplotlib.lines.Line2D at 0x17c3d232a80>,
#  <matplotlib.lines.Line2D at 0x17c3d232ff0>,
#  <matplotlib.lines.Line2D at 0x17c3d232fc0>,
#  <matplotlib.lines.Line2D at 0x17c3d232e40>,
#  <matplotlib.lines.Line2D at 0x17c3d231ee0>,
#  <matplotlib.lines.Line2D at 0x17c3d231700>,
#  <matplotlib.lines.Line2D at 0x17c3d231880>,
#  <matplotlib.lines.Line2D at 0x17c3d231940>,
#  <matplotlib.lines.Line2D at 0x17c3d233050>,
#  <matplotlib.lines.Line2D at 0x17c3d2332f0>,
#  <matplotlib.lines.Line2D at 0x17c3d2332c0>,
#  <matplotlib.lines.Line2D at 0x17c3d233230>,
#  <matplotlib.lines.Line2D at 0x17c3d2335f0>,
#  <matplotlib.lines.Line2D at 0x17c3d233890>,
#  <matplotlib.lines.Line2D at 0x17c3d233860>,
#  <matplotlib.lines.Line2D at 0x17c3d2337d0>,
#  <matplotlib.lines.Line2D at 0x17c3d233bc0>,
#  <matplotlib.lines.Line2D at 0x179a7d156a0>,
#  <matplotlib.lines.Line2D at 0x17c3d233fb0>,
#  <matplotlib.lines.Line2D at 0x17c3d233d40>,
#  <matplotlib.lines.Line2D at 0x17c3d233560>,
#  <matplotlib.lines.Line2D at 0x17c3d2304d0>,
#  <matplotlib.lines.Line2D at 0x17c3d231ac0>,
#  <matplotlib.lines.Line2D at 0x17c3d2325a0>,
#  <matplotlib.lines.Line2D at 0x17c3d232090>,
#  <matplotlib.lines.Line2D at 0x17c3d231e20>,
#  <matplotlib.lines.Line2D at 0x17c3d231490>,
#  <matplotlib.lines.Line2D at 0x17c3d2945f0>,
#  <matplotlib.lines.Line2D at 0x17c3d2945c0>,
#  <matplotlib.lines.Line2D at 0x17c3d294650>,
#  <matplotlib.lines.Line2D at 0x17c3d2949e0>,
#  <matplotlib.lines.Line2D at 0x17c3d294b30>,
#  <matplotlib.lines.Line2D at 0x17c3d294e30>,
#  <matplotlib.lines.Line2D at 0x17c3d294dd0>,
#  <matplotlib.lines.Line2D at 0x17c3d2953a0>,
#  <matplotlib.lines.Line2D at 0x17c3d295550>,
#  <matplotlib.lines.Line2D at 0x17c3d295460>,
#  <matplotlib.lines.Line2D at 0x17c3d295640>,
#  <matplotlib.lines.Line2D at 0x17c3d295c70>,
#  <matplotlib.lines.Line2D at 0x17c3d295850>,
#  <matplotlib.lines.Line2D at 0x17c3d295dc0>,
#  <matplotlib.lines.Line2D at 0x17c3d2c6cc0>,
#  <matplotlib.lines.Line2D at 0x17c3d2952e0>,
#  <matplotlib.lines.Line2D at 0x17c3d294080>,
#  <matplotlib.lines.Line2D at 0x17c3d296060>,
#  <matplotlib.lines.Line2D at 0x17c3d295fa0>,
#  <matplotlib.lines.Line2D at 0x17c3d2960f0>,
#  <matplotlib.lines.Line2D at 0x17c3d296330>,
#  <matplotlib.lines.Line2D at 0x17c3d296600>,
#  <matplotlib.lines.Line2D at 0x17c3d296810>,
#  <matplotlib.lines.Line2D at 0x17c3d2969c0>,
#  <matplotlib.lines.Line2D at 0x17c3d296ae0>,
#  <matplotlib.lines.Line2D at 0x17c3d296e40>,
#  <matplotlib.lines.Line2D at 0x17c3d297200>,
#  <matplotlib.lines.Line2D at 0x17c3d2971a0>,
#  <matplotlib.lines.Line2D at 0x17c3d2974a0>,
#  <matplotlib.lines.Line2D at 0x17c3d2979b0>,
#  <matplotlib.lines.Line2D at 0x17c3d297a10>,
#  <matplotlib.lines.Line2D at 0x17c3d296f30>,
#  <matplotlib.lines.Line2D at 0x17c3d296900>,
#  <matplotlib.lines.Line2D at 0x17c3d295f70>,
#  <matplotlib.lines.Line2D at 0x17c3d295b80>,
#  <matplotlib.lines.Line2D at 0x17c3d295490>,
#  <matplotlib.lines.Line2D at 0x17c3d297c20>,
#  <matplotlib.lines.Line2D at 0x17c3d297fb0>,
#  <matplotlib.lines.Line2D at 0x17c3d297ef0>,
#  <matplotlib.lines.Line2D at 0x17c3d297ec0>,
#  <matplotlib.lines.Line2D at 0x17c3d2968a0>,
#  <matplotlib.lines.Line2D at 0x17c3d296d80>,
#  <matplotlib.lines.Line2D at 0x17c3d2960c0>,
#  <matplotlib.lines.Line2D at 0x17c3d297b60>,
#  <matplotlib.lines.Line2D at 0x17c3d294500>,
#  <matplotlib.lines.Line2D at 0x17c3d296ab0>,
#  <matplotlib.lines.Line2D at 0x17c3d295880>,
#  <matplotlib.lines.Line2D at 0x17c3d295be0>,
#  <matplotlib.lines.Line2D at 0x17c3d296930>,
#  <matplotlib.lines.Line2D at 0x17c3d24d1f0>,
#  <matplotlib.lines.Line2D at 0x17c3d24c110>,
#  <matplotlib.lines.Line2D at 0x17c3d24fe00>,
#  <matplotlib.lines.Line2D at 0x17c3d24dd30>,
#  <matplotlib.lines.Line2D at 0x17c3d24e600>,
#  <matplotlib.lines.Line2D at 0x17c3d24c0b0>,
#  <matplotlib.lines.Line2D at 0x17c3d24c4d0>,
#  <matplotlib.lines.Line2D at 0x17c3d24c470>,
#  <matplotlib.lines.Line2D at 0x17c3d24c590>,
#  <matplotlib.lines.Line2D at 0x17c3d24c9e0>,
#  <matplotlib.lines.Line2D at 0x17c3d24caa0>,
#  <matplotlib.lines.Line2D at 0x17c3d24cc50>,
#  <matplotlib.lines.Line2D at 0x17c3d223500>,
#  <matplotlib.lines.Line2D at 0x17c3d24ce00>,
#  <matplotlib.lines.Line2D at 0x17c3d24d340>,
#  <matplotlib.lines.Line2D at 0x17c3d24d6a0>,
#  <matplotlib.lines.Line2D at 0x17c3d24dac0>,
#  <matplotlib.lines.Line2D at 0x17c3d24da90>,
#  <matplotlib.lines.Line2D at 0x17c3d24cc20>,
#  <matplotlib.lines.Line2D at 0x17c3d24c440>,
#  <matplotlib.lines.Line2D at 0x17c3d24dbe0>,
#  <matplotlib.lines.Line2D at 0x17c3d24db20>,
#  <matplotlib.lines.Line2D at 0x17c3d24ddf0>,
#  <matplotlib.lines.Line2D at 0x17c3d24deb0>,
#  <matplotlib.lines.Line2D at 0x17c3d24e120>,
#  <matplotlib.lines.Line2D at 0x17c3d24e2d0>,
#  <matplotlib.lines.Line2D at 0x17c3d24e480>,
#  <matplotlib.lines.Line2D at 0x17c3d24e780>,
#  <matplotlib.lines.Line2D at 0x17c3d24eb40>,
#  <matplotlib.lines.Line2D at 0x17c3d24ea50>,
#  <matplotlib.lines.Line2D at 0x17c3d24eff0>,
#  <matplotlib.lines.Line2D at 0x17c3d24f320>,
#  <matplotlib.lines.Line2D at 0x17c3d24f4d0>,
#  <matplotlib.lines.Line2D at 0x17c3d24f0b0>,
#  <matplotlib.lines.Line2D at 0x17c3d24e8d0>,
#  <matplotlib.lines.Line2D at 0x179a7d14920>,
#  <matplotlib.lines.Line2D at 0x17c3d24e330>,
#  <matplotlib.lines.Line2D at 0x17c3d24c1d0>,
#  <matplotlib.lines.Line2D at 0x17c3d24d310>,
#  <matplotlib.lines.Line2D at 0x17c3d24c8f0>,
#  <matplotlib.lines.Line2D at 0x17c3d24f950>,
#  <matplotlib.lines.Line2D at 0x17c3d24f8f0>,
#  <matplotlib.lines.Line2D at 0x17c3d24faa0>,
#  <matplotlib.lines.Line2D at 0x17c3d24fc80>,
#  <matplotlib.lines.Line2D at 0x17c3d24ff80>,
#  <matplotlib.lines.Line2D at 0x17c3d24fa40>,
#  <matplotlib.lines.Line2D at 0x17c3d24f920>,
#  <matplotlib.lines.Line2D at 0x17c3d24f680>,
#  <matplotlib.lines.Line2D at 0x17c3d24f6e0>,
#  <matplotlib.lines.Line2D at 0x17c3d24fc50>,
#  <matplotlib.lines.Line2D at 0x17c3d24ffb0>,
#  <matplotlib.lines.Line2D at 0x17c3d24ec60>,
#  <matplotlib.lines.Line2D at 0x17c3d24f8c0>,
#  <matplotlib.lines.Line2D at 0x17c3d24e570>,
#  <matplotlib.lines.Line2D at 0x17c3d24f2f0>,
#  <matplotlib.lines.Line2D at 0x17c3d24d3a0>,
#  <matplotlib.lines.Line2D at 0x17c3cd6bd70>,
#  <matplotlib.lines.Line2D at 0x17c3cd6bef0>,
#  <matplotlib.lines.Line2D at 0x17c3d2635f0>,
#  <matplotlib.lines.Line2D at 0x17c3d263f80>,
#  <matplotlib.lines.Line2D at 0x17c3d261f40>,
#  <matplotlib.lines.Line2D at 0x17c3d262f60>,
#  <matplotlib.lines.Line2D at 0x17c3d2638c0>,
#  <matplotlib.lines.Line2D at 0x17c3d261e20>,
#  <matplotlib.lines.Line2D at 0x17c3d262630>,
#  <matplotlib.lines.Line2D at 0x17c3d260920>,
#  <matplotlib.lines.Line2D at 0x17c3d261760>,
#  <matplotlib.lines.Line2D at 0x17c3d262ba0>,
#  <matplotlib.lines.Line2D at 0x17c3d262030>,
#  <matplotlib.lines.Line2D at 0x17c3d260560>,
#  <matplotlib.lines.Line2D at 0x17c3d261880>,
#  <matplotlib.lines.Line2D at 0x17c3d263bf0>,
#  <matplotlib.lines.Line2D at 0x17c3d263f50>,
#  <matplotlib.lines.Line2D at 0x17c3d260170>,
#  <matplotlib.lines.Line2D at 0x17c3d2600e0>,
#  <matplotlib.lines.Line2D at 0x17c3d260350>,
#  <matplotlib.lines.Line2D at 0x17c3d260710>,
#  <matplotlib.lines.Line2D at 0x17c3d2609b0>,
#  <matplotlib.lines.Line2D at 0x17c3d260950>,
#  <matplotlib.lines.Line2D at 0x17c3d260b90>,
#  <matplotlib.lines.Line2D at 0x17c3d260f80>,
#  <matplotlib.lines.Line2D at 0x17c3d260e60>,
#  <matplotlib.lines.Line2D at 0x17c3d2612e0>,
#  <matplotlib.lines.Line2D at 0x17c3d261430>,
#  <matplotlib.lines.Line2D at 0x17c3d2619a0>,
#  <matplotlib.lines.Line2D at 0x17c3d2618b0>,
#  <matplotlib.lines.Line2D at 0x17c3d261c10>,
#  <matplotlib.lines.Line2D at 0x17c3d261010>,
#  <matplotlib.lines.Line2D at 0x17c3d260320>,
#  <matplotlib.lines.Line2D at 0x17c3d2606e0>,
#  <matplotlib.lines.Line2D at 0x17c3d260110>,
#  <matplotlib.lines.Line2D at 0x17c3d261dc0>,
#  <matplotlib.lines.Line2D at 0x17c3d262000>,
#  <matplotlib.lines.Line2D at 0x17c3d2622d0>,
#  <matplotlib.lines.Line2D at 0x17c3d262420>,
#  <matplotlib.lines.Line2D at 0x17c3d262690>,
#  <matplotlib.lines.Line2D at 0x17c3d262780>,
#  <matplotlib.lines.Line2D at 0x17c3d262b10>,
#  <matplotlib.lines.Line2D at 0x17c3d262a20>,
#  <matplotlib.lines.Line2D at 0x17c3d2631a0>,
#  <matplotlib.lines.Line2D at 0x17c3d263350>,
#  <matplotlib.lines.Line2D at 0x17c3d263440>,
#  <matplotlib.lines.Line2D at 0x17c3d263650>,
#  <matplotlib.lines.Line2D at 0x17c3d262840>,
#  <matplotlib.lines.Line2D at 0x17c3d2625a0>,
#  <matplotlib.lines.Line2D at 0x17c3d260680>,
#  <matplotlib.lines.Line2D at 0x17c3d260230>,
#  <matplotlib.lines.Line2D at 0x17c3d260c80>,
#  <matplotlib.lines.Line2D at 0x17c3d2638f0>,
#  <matplotlib.lines.Line2D at 0x17c3d263b60>,
#  <matplotlib.lines.Line2D at 0x17c3d263aa0>,
#  <matplotlib.lines.Line2D at 0x17c3d263ec0>,
#  <matplotlib.lines.Line2D at 0x17c3d263b00>,
#  <matplotlib.lines.Line2D at 0x17c3ce97d70>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6870>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6ff0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6f30>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6150>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6ae0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6d50>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6180>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6360>,
#  <matplotlib.lines.Line2D at 0x17c3d1b4c50>,
#  <matplotlib.lines.Line2D at 0x17c3d1b4b90>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6db0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6e70>,
#  <matplotlib.lines.Line2D at 0x17c3d1b77d0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b5280>,
#  <matplotlib.lines.Line2D at 0x17c3d1b5010>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6ed0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b5820>,
#  <matplotlib.lines.Line2D at 0x17c3d1b5d30>,
#  <matplotlib.lines.Line2D at 0x17c3d1b45c0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6210>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6810>,
#  <matplotlib.lines.Line2D at 0x17c3d1b64e0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6090>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6330>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6de0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b69f0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b79e0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6ab0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b40e0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b5250>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6420>,
#  <matplotlib.lines.Line2D at 0x17c3d1b68a0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b5f40>,
#  <matplotlib.lines.Line2D at 0x17c3d1b5eb0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b6a80>,
#  <matplotlib.lines.Line2D at 0x17c3d1b5f70>,
#  <matplotlib.lines.Line2D at 0x17c3d1b4cb0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b54c0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b5310>,
#  <matplotlib.lines.Line2D at 0x17c3d1b40b0>,
#  <matplotlib.lines.Line2D at 0x17c3d1b4200>,
#  <matplotlib.lines.Line2D at 0x17c3d1b5b50>,
#  <matplotlib.lines.Line2D at 0x17c3d1b5a00>,
#  <matplotlib.lines.Line2D at 0x17c3d1b5940>,
#  <matplotlib.lines.Line2D at 0x17c3d254d40>,
#  <matplotlib.lines.Line2D at 0x17c3d254dd0>,
#  <matplotlib.lines.Line2D at 0x17c3d2549e0>,
#  <matplotlib.lines.Line2D at 0x17c3d254a70>,
#  <matplotlib.lines.Line2D at 0x17c3d254650>,
#  <matplotlib.lines.Line2D at 0x17c3d254350>,
#  <matplotlib.lines.Line2D at 0x17c3d254080>,
#  <matplotlib.lines.Line2D at 0x17c3d254920>,
#  <matplotlib.lines.Line2D at 0x17c3d254620>,
#  <matplotlib.lines.Line2D at 0x17c3d254170>,
#  <matplotlib.lines.Line2D at 0x17c3d254d70>,
#  <matplotlib.lines.Line2D at 0x17c3d254ec0>,
#  <matplotlib.lines.Line2D at 0x17c3d254fb0>,
#  <matplotlib.lines.Line2D at 0x17c3d2550a0>,
#  <matplotlib.lines.Line2D at 0x17c3d255190>,
#  <matplotlib.lines.Line2D at 0x17c3d255280>,
#  <matplotlib.lines.Line2D at 0x17c3d255370>,
#  <matplotlib.lines.Line2D at 0x17c3d255460>,
#  <matplotlib.lines.Line2D at 0x17c3d255550>,
#  <matplotlib.lines.Line2D at 0x17c3d255640>,
#  <matplotlib.lines.Line2D at 0x17c3d255730>,
#  <matplotlib.lines.Line2D at 0x17c3d255820>,
#  <matplotlib.lines.Line2D at 0x17c3d255910>,
#  <matplotlib.lines.Line2D at 0x17c3d255a00>,
#  <matplotlib.lines.Line2D at 0x17c3d255af0>,
#  <matplotlib.lines.Line2D at 0x17c3d255be0>,
#  <matplotlib.lines.Line2D at 0x17c3d255cd0>,
#  <matplotlib.lines.Line2D at 0x17c3d255dc0>,
#  <matplotlib.lines.Line2D at 0x17c3d255eb0>,
#  <matplotlib.lines.Line2D at 0x17c3d255fa0>,
#  <matplotlib.lines.Line2D at 0x17c3d256090>,
#  <matplotlib.lines.Line2D at 0x17c3d256180>,
#  <matplotlib.lines.Line2D at 0x17c3d256270>,
#  <matplotlib.lines.Line2D at 0x17c3d256360>,
#  <matplotlib.lines.Line2D at 0x17c3d256450>,
#  <matplotlib.lines.Line2D at 0x17c3d256540>,
#  <matplotlib.lines.Line2D at 0x17c3d256630>,
#  <matplotlib.lines.Line2D at 0x17c3d256720>,
#  <matplotlib.lines.Line2D at 0x17c3d256810>,
#  <matplotlib.lines.Line2D at 0x17c3d256900>,
#  <matplotlib.lines.Line2D at 0x17c3d2569f0>,
#  <matplotlib.lines.Line2D at 0x17c3d256ae0>,
#  <matplotlib.lines.Line2D at 0x17c3d256bd0>,
#  <matplotlib.lines.Line2D at 0x17c3d256cc0>,
#  <matplotlib.lines.Line2D at 0x17c3d256db0>,
#  <matplotlib.lines.Line2D at 0x17c3d256ea0>,
#  <matplotlib.lines.Line2D at 0x17c3d256f90>,
#  <matplotlib.lines.Line2D at 0x17c3d257080>,
#  <matplotlib.lines.Line2D at 0x17c3d257170>,
#  <matplotlib.lines.Line2D at 0x17c3d257260>,
#  <matplotlib.lines.Line2D at 0x17c3d257350>,
#  <matplotlib.lines.Line2D at 0x17c3d257440>,
#  <matplotlib.lines.Line2D at 0x17c3d257530>,
#  <matplotlib.lines.Line2D at 0x17c3d257620>,
#  <matplotlib.lines.Line2D at 0x17c3d257710>,
#  <matplotlib.lines.Line2D at 0x17c3d257800>,
#  <matplotlib.lines.Line2D at 0x17c3d2578f0>,
#  <matplotlib.lines.Line2D at 0x17c3d2579e0>,
#  <matplotlib.lines.Line2D at 0x17c3d257ad0>,
#  <matplotlib.lines.Line2D at 0x17c3d257bc0>,
#  <matplotlib.lines.Line2D at 0x17c3d257cb0>,
#  <matplotlib.lines.Line2D at 0x17c3d257da0>,
#  <matplotlib.lines.Line2D at 0x17c3d257e90>,
#  <matplotlib.lines.Line2D at 0x17c3d257f80>,
#  <matplotlib.lines.Line2D at 0x17c3d3640b0>,
#  <matplotlib.lines.Line2D at 0x17c3d3641a0>,
#  <matplotlib.lines.Line2D at 0x17c3d364290>,
#  <matplotlib.lines.Line2D at 0x17c3d364380>,
#  <matplotlib.lines.Line2D at 0x17c3d364470>,
#  ...]
