# %%
import numpy as np
import pandas as pd
from alg_repository.data_importer import DataImporter as di
import os
file_names = os.listdir('CSV file rep')
file_path = 'CSV file rep/'
current_A_angle_begin = di(',',file_path + file_names[0]).main_process()
current_A_angle_end = di(',',file_path + file_names[1]).main_process()
current_B_angle_begin = di(',',file_path + file_names[2]).main_process()
current_B_angle_end = di(',',file_path + file_names[3]).main_process()
current_C_angle_begin = di(',',file_path + file_names[4]).main_process()
current_C_angle_end = di(',',file_path + file_names[5]).main_process()
current_A_begin = di(',',file_path + file_names[6]).main_process()
current_A_end = di(',',file_path + file_names[7]).main_process()
current_B_begin = di(',',file_path + file_names[8]).main_process()
current_B_end = di(',',file_path + file_names[9]).main_process()
current_C_begin = di(',',file_path + file_names[10]).main_process()
current_C_end = di(',',file_path + file_names[11]).main_process()
voltage_A_angle_begin = di(',',file_path + file_names[12]).main_process()
voltage_A_angle_end = di(',',file_path + file_names[13]).main_process()
voltage_B_angle_begin = di(',',file_path + file_names[14]).main_process()
voltage_B_angle_end = di(',',file_path + file_names[15]).main_process()
voltage_C_angle_begin = di(',',file_path + file_names[16]).main_process()
voltage_C_angle_end = di(',',file_path + file_names[17]).main_process()
voltage_A_begin = di(',',file_path + file_names[18]).main_process()
voltage_A_end = di(',',file_path + file_names[19]).main_process()
voltage_B_begin = di(',',file_path + file_names[20]).main_process()
voltage_B_end = di(',',file_path + file_names[21]).main_process()
voltage_C_begin = di(',',file_path + file_names[22]).main_process()
voltage_C_end = di(',',file_path + file_names[23]).main_process()
time = di(',',file_path + file_names[24]).main_process()
time['Time'] = pd.to_datetime(time['Time'], unit='s', origin='unix').dt.strftime('%S.%f')

def rename_columns(data_current):
    columns_name = []
    for indx in range(len(data_current.columns)):
        columns_name.append('exp ' + str(indx + 1))

    data_current.columns = columns_name
    return data_current

current_A_begin = rename_columns(current_A_begin)
current_B_begin = rename_columns(current_B_begin)
current_C_begin = rename_columns(current_C_begin)
current_A_angle_begin = rename_columns(current_A_angle_begin)
current_A_angle_end =  rename_columns(current_A_angle_end)
current_B_angle_begin = rename_columns(current_B_angle_begin)
current_B_angle_end = rename_columns(current_B_angle_end)
current_C_angle_begin = rename_columns(current_C_angle_begin)
current_C_angle_end = rename_columns(current_C_angle_end)
current_A_begin = rename_columns(current_A_begin)
current_A_end = rename_columns(current_A_end)
current_B_begin = rename_columns(current_B_begin)
current_B_end = rename_columns(current_B_end)
current_C_begin = rename_columns(current_C_begin)
current_C_end = rename_columns(current_C_end)
voltage_A_angle_begin = rename_columns(voltage_A_angle_begin)
voltage_A_angle_end = rename_columns(voltage_A_angle_end)
voltage_B_angle_begin = rename_columns(voltage_B_angle_begin)
voltage_B_angle_end = rename_columns(voltage_B_angle_end)
voltage_C_angle_begin = rename_columns(voltage_C_angle_begin)
voltage_C_angle_end = rename_columns(voltage_C_angle_end)
voltage_A_begin = rename_columns(voltage_A_begin)
voltage_A_end = rename_columns(voltage_A_end)
voltage_B_begin = rename_columns(voltage_B_begin)
voltage_B_end = rename_columns(voltage_B_end)
voltage_C_begin = rename_columns(voltage_C_begin)
voltage_C_end = rename_columns(voltage_C_end)

# %%
# Инициализация временных переменных для выгрузки экспериментов
data_current_A_beg = []
data_current_B_beg = []
data_current_C_beg = []
data_current_A_end = []
data_current_B_end = []
data_current_C_end = []
data_voltage_A_beg = []
data_voltage_B_beg = []
data_voltage_C_beg = []
data_voltage_A_end = []
data_voltage_B_end = []
data_voltage_C_end = []
data_current_A_beg_ang = []
data_current_B_beg_ang = []
data_current_C_beg_ang = []
data_current_A_end_ang = []
data_current_B_end_ang = []
data_current_C_end_ang = []
data_voltage_A_beg_ang = []
data_voltage_B_beg_ang = []
data_voltage_C_beg_ang = []
data_voltage_A_end_ang = []
data_voltage_B_end_ang = []
data_voltage_C_end_ang = []


# Сборка групп данных
for indx in range(3000):
    # Подгрузка данных и сбор их в отдельные ячейки по экспериментам
    exp_name = 'exp ' + str(indx + 1)
    data_current_A_beg.append([current_A_begin[exp_name].reset_index(drop=True).values])
    data_current_B_beg.append([current_B_begin[exp_name].reset_index(drop=True).values])
    data_current_C_beg.append([current_C_begin[exp_name].reset_index(drop=True).values])
    data_current_A_end.append([current_A_end[exp_name].reset_index(drop=True).values])
    data_current_B_end.append([current_B_end[exp_name].reset_index(drop=True).values])
    data_current_C_end.append([current_C_end[exp_name].reset_index(drop=True).values])
    data_voltage_A_beg.append([voltage_A_begin[exp_name].reset_index(drop=True).values])
    data_voltage_B_beg.append([voltage_B_begin[exp_name].reset_index(drop=True).values])
    data_voltage_C_beg.append([voltage_C_begin[exp_name].reset_index(drop=True).values])
    data_voltage_A_end.append([voltage_A_end[exp_name].reset_index(drop=True).values])
    data_voltage_B_end.append([voltage_B_end[exp_name].reset_index(drop=True).values])
    data_voltage_C_end.append([voltage_C_end[exp_name].reset_index(drop=True).values])
    data_current_A_beg_ang.append([current_A_angle_begin[exp_name].reset_index(drop=True).values])
    data_current_B_beg_ang.append([current_B_angle_begin[exp_name].reset_index(drop=True).values])
    data_current_C_beg_ang.append([current_C_angle_begin[exp_name].reset_index(drop=True).values])
    data_current_A_end_ang.append([current_A_angle_end[exp_name].reset_index(drop=True).values])
    data_current_B_end_ang.append([current_B_angle_end[exp_name].reset_index(drop=True).values])
    data_current_C_end_ang.append([current_C_angle_end[exp_name].reset_index(drop=True).values])
    data_voltage_A_beg_ang.append([voltage_A_angle_begin[exp_name].reset_index(drop=True).values])
    data_voltage_B_beg_ang.append([voltage_B_angle_begin[exp_name].reset_index(drop=True).values])
    data_voltage_C_beg_ang.append([voltage_C_angle_begin[exp_name].reset_index(drop=True).values])
    data_voltage_A_end_ang.append([voltage_A_angle_end[exp_name].reset_index(drop=True).values])
    data_voltage_B_end_ang.append([voltage_B_angle_end[exp_name].reset_index(drop=True).values])
    data_voltage_C_end_ang.append([voltage_C_angle_end[exp_name].reset_index(drop=True).values])

# Сборка данных в один список
data_current_beg = np.concatenate((np.array(data_current_A_beg),
                                  np.array(data_current_B_beg),
                                  np.array(data_current_C_beg)), axis = 1)
data_current_end = np.concatenate((np.array(data_current_A_end),
                                  np.array(data_current_B_end),
                                  np.array(data_current_C_end)), axis = 1)
data_voltage_beg = np.concatenate((np.array(data_voltage_A_beg),
                                  np.array(data_voltage_B_beg),
                                  np.array(data_voltage_C_beg)), axis = 1)
data_voltage_end = np.concatenate((np.array(data_voltage_A_end),
                                  np.array(data_voltage_B_end),
                                  np.array(data_voltage_C_end)), axis = 1)
data_current_beg_ang = np.concatenate((np.array(data_current_A_beg_ang),
                                       np.array(data_current_B_beg_ang),
                                       np.array(data_current_C_beg_ang)), axis = 1)
data_current_end_ang = np.concatenate((np.array(data_current_A_end_ang),
                                       np.array(data_current_B_end_ang),
                                       np.array(data_current_C_end_ang)), axis = 1)
data_voltage_beg_ang = np.concatenate((np.array(data_voltage_A_beg_ang),
                                       np.array(data_voltage_B_beg_ang),
                                       np.array(data_voltage_C_beg_ang)), axis = 1)
data_voltage_end_ang = np.concatenate((np.array(data_voltage_A_end_ang),
                                       np.array(data_voltage_B_end_ang),
                                       np.array(data_voltage_C_end_ang)), axis = 1)

# %%
data.append([exp_data[exp, key].reset_index(drop=True).values])

# %%
с = current_A_begin['exp 1']

# %%
best_method = di(';', 'best_method.csv').main_process()

# %%
exp_names = pd.Series(best_method.columns)
feature_names = pd.Series(voltage_C_end.columns)[:3000]
exp_data = pd.DataFrame()

for feature_name in feature_names:
    
    df = pd.DataFrame(
    {
        'time': time['Time'],
        'current A beg': current_A_begin[feature_name],
        'current A end': current_A_end[feature_name],
        'current B beg': current_B_begin[feature_name],
        'current B end': current_B_end[feature_name],
        'current C beg': current_C_begin[feature_name],
        'current C end': current_C_end[feature_name],
        'current A angle begin': current_A_angle_begin[feature_name],
        'current_A_angle_end': current_A_angle_end[feature_name],
        'current_B_angle_begin': current_B_angle_begin[feature_name],
        'current_B_angle_end': current_B_angle_end[feature_name],
        'current_C_angle_begin': current_C_angle_begin[feature_name],
        'current_C_angle_end': current_C_angle_end[feature_name],
        'voltage_A_begin': voltage_A_begin[feature_name],
        'voltage_A_end': voltage_A_end[feature_name],
        'voltage_B_begin': voltage_B_begin[feature_name],
        'voltage_B_end': voltage_B_end[feature_name],
        'voltage_C_begin': voltage_C_begin[feature_name],
        'voltage_C_end': voltage_C_end[feature_name],
        'voltage_A_angle_begin': voltage_A_angle_begin[feature_name],
        'voltage_A_angle_end': voltage_A_angle_end[feature_name],
        'voltage_B_angle_begin': voltage_B_angle_begin[feature_name],
        'voltage_B_angle_end': voltage_B_angle_end[feature_name],
        'voltage_C_angle_begin': voltage_C_angle_begin[feature_name],
        'voltage_C_angle_end': voltage_C_angle_end[feature_name]
    }
    )
    df = df.set_index('time')
    df = df.transpose()

    names = pd.DataFrame({ 'Exp Num': []})
    for i in range(len(df)):
        name = pd.DataFrame({
            'Exp Num': pd.Series([feature_name], index=[i])
            })
        names = pd.concat([names, name], ignore_index=True)
    names.index = df.index
    
    df = pd.concat([df, names], axis=1)
    df = df.set_index(['Exp Num', df.index])

    exp_data = pd.concat([exp_data, df], axis = 0)

# %%
exp_data
# Out:
#                                   00.150000    00.150100    00.150200  \
# Exp Num
# exp 1    current A beg          2137.969451  2137.969451  2137.969451
#          current A end          2130.927577  2130.927577  2130.927577
#          current B beg          2142.654519  2142.654519  2142.654519
#          current B end          2134.129876  2134.129876  2134.129876
#          current C beg          2148.240030  2148.240030  2148.240030
# ...                                     ...          ...          ...
# exp 3000 voltage_A_angle_end      -1.191631    -1.191631    -1.191631
#          voltage_B_angle_begin     2.982933     2.982933     2.982933
#          voltage_B_angle_end       2.991544     2.991544     2.991544
#          voltage_C_angle_begin     0.887224     0.887224     0.887224
#          voltage_C_angle_end       0.896469     0.896469     0.896469
#
#                                   00.150300    00.150400    00.150500  \
# Exp Num
# exp 1    current A beg          2137.969451  2137.969451  2137.969451
#          current A end          2130.927577  2130.927577  2130.927577
#          current B beg          2142.654519  2142.654519  2142.654519
#          current B end          2134.129876  2134.129876  2134.129876
#          current C beg          2148.240030  2148.240030  2148.240030
# ...                                     ...          ...          ...
# exp 3000 voltage_A_angle_end      -1.191631    -1.191631    -1.191631
#          voltage_B_angle_begin     2.982933     2.982933     2.982933
#          voltage_B_angle_end       2.991544     2.991544     2.991544
#          voltage_C_angle_begin     0.887224     0.887224     0.887224
#          voltage_C_angle_end       0.896469     0.896469     0.896469
#
#                                   00.150600    00.150700    00.150800  \
# Exp Num
# exp 1    current A beg          2137.969451  2137.969451  2137.969451
#          current A end          2130.927577  2130.927577  2130.927577
#          current B beg          2142.654519  2142.654519  2142.654519
#          current B end          2134.129876  2134.129876  2134.129876
#          current C beg          2148.240030  2148.240030  2148.240030
# ...                                     ...          ...          ...
# exp 3000 voltage_A_angle_end      -1.191631    -1.191631    -1.191631
#          voltage_B_angle_begin     2.982933     2.982933     2.982933
#          voltage_B_angle_end       2.991544     2.991544     2.991544
#          voltage_C_angle_begin     0.887224     0.887224     0.887224
#          voltage_C_angle_end       0.896469     0.896469     0.896469
#
#                                   00.150900  ...    00.999000    00.999100  \
# Exp Num                                      ...
# exp 1    current A beg          2137.969451  ...  2137.969833  2137.969833
#          current A end          2130.927577  ...  2130.927577  2130.927577
#          current B beg          2142.654519  ...  2142.651159  2142.651159
#          current B end          2134.129876  ...  2134.122874  2134.122874
#          current C beg          2148.240030  ...  2148.249851  2148.249851
# ...                                     ...  ...          ...          ...
# exp 3000 voltage_A_angle_end      -1.191631  ...    -1.191631    -1.191631
#          voltage_B_angle_begin     2.982933  ...     2.982933     2.982933
#          voltage_B_angle_end       2.991544  ...     2.991544     2.991544
#          voltage_C_angle_begin     0.887224  ...     0.887224     0.887224
#          voltage_C_angle_end       0.896469  ...     0.896469     0.896469
#
#                                   00.999200    00.999300    00.999400  \
# Exp Num
# exp 1    current A beg          2137.969833  2137.969833  2137.969833
#          current A end          2130.927577  2130.927577  2130.927577
#          current B beg          2142.651159  2142.651159  2142.651159
#          current B end          2134.122874  2134.122874  2134.122874
#          current C beg          2148.249851  2148.249851  2148.249851
# ...                                     ...          ...          ...
# exp 3000 voltage_A_angle_end      -1.191631    -1.191631    -1.191631
#          voltage_B_angle_begin     2.982933     2.982933     2.982933
#          voltage_B_angle_end       2.991544     2.991544     2.991544
#          voltage_C_angle_begin     0.887224     0.887224     0.887224
#          voltage_C_angle_end       0.896469     0.896469     0.896469
#
#                                   00.999500    00.999600    00.999700  \
# Exp Num
# exp 1    current A beg          2137.969833  2137.969833  2137.969833
#          current A end          2130.927577  2130.927577  2130.927577
#          current B beg          2142.651159  2142.651159  2142.651159
#          current B end          2134.122874  2134.122874  2134.122874
#          current C beg          2148.249851  2148.249851  2148.249851
# ...                                     ...          ...          ...
# exp 3000 voltage_A_angle_end      -1.191631    -1.191631    -1.191631
#          voltage_B_angle_begin     2.982933     2.982933     2.982933
#          voltage_B_angle_end       2.991544     2.991544     2.991544
#          voltage_C_angle_begin     0.887224     0.887224     0.887224
#          voltage_C_angle_end       0.896469     0.896469     0.896469
#
#                                   00.999800    00.999900
# Exp Num
# exp 1    current A beg          2137.969833  2137.969833
#          current A end          2130.927577  2130.927577
#          current B beg          2142.651159  2142.651159
#          current B end          2134.122874  2134.122874
#          current C beg          2148.249851  2148.249851
# ...                                     ...          ...
# exp 3000 voltage_A_angle_end      -1.191631    -1.191631
#          voltage_B_angle_begin     2.982933     2.982933
#          voltage_B_angle_end       2.991544     2.991544
#          voltage_C_angle_begin     0.887224     0.887224
#          voltage_C_angle_end       0.896469     0.896469
#
# [72000 rows x 8500 columns]

# %%
exp_data.to_csv('exp_data.csv')

# %%
from alg_repository.data_importer import DataImporter as di

exp_data = di(',', 'exp_data.csv').main_process()
exp_data = exp_data.rename(columns={'Unnamed: 1': 'Name of meas'})
exp_data = exp_data.set_index(['Exp Num', 'Name of meas'])
exp_data = exp_data.transpose()

# %%
exp_data = exp_data.rename(columns={'Unnamed: 1': 'Name of meas'})

# %%
exp_data = exp_data.set_index(['Exp Num', 'Name of meas'])

# %%
exp_data = exp_data.transpose()

# %%
exp_data
# Out:
# Exp Num              exp 1                                            \
# Name of meas current A beg current A end current B beg current B end
# 00.150000      2137.969451   2130.927577   2142.654519   2134.129876
# 00.150100      2137.969451   2130.927577   2142.654519   2134.129876
# 00.150200      2137.969451   2130.927577   2142.654519   2134.129876
# 00.150300      2137.969451   2130.927577   2142.654519   2134.129876
# 00.150400      2137.969451   2130.927577   2142.654519   2134.129876
# ...                    ...           ...           ...           ...
# 00.999500      2137.969833   2130.927577   2142.651159   2134.122874
# 00.999600      2137.969833   2130.927577   2142.651159   2134.122874
# 00.999700      2137.969833   2130.927577   2142.651159   2134.122874
# 00.999800      2137.969833   2130.927577   2142.651159   2134.122874
# 00.999900      2137.969833   2130.927577   2142.651159   2134.122874
#
# Exp Num                                                         \
# Name of meas current C beg current C end current_A_angle_begin
# 00.150000      2148.240030   2139.885860             -0.460910
# 00.150100      2148.240030   2139.885860             -0.460910
# 00.150200      2148.240030   2139.885860             -0.460910
# 00.150300      2148.240030   2139.885860             -0.460910
# 00.150400      2148.240030   2139.885860             -0.460910
# ...                    ...           ...                   ...
# 00.999500      2148.249851   2139.879035             -0.460907
# 00.999600      2148.249851   2139.879035             -0.460907
# 00.999700      2148.249851   2139.879035             -0.460907
# 00.999800      2148.249851   2139.879035             -0.460907
# 00.999900      2148.249851   2139.879035             -0.460907
#
# Exp Num                                                                     \
# Name of meas current_A_angle_end current_B_angle_begin current_B_angle_end
# 00.150000                2.59079             -2.550256            0.501271
# 00.150100                2.59079             -2.550256            0.501271
# 00.150200                2.59079             -2.550256            0.501271
# 00.150300                2.59079             -2.550256            0.501271
# 00.150400                2.59079             -2.550256            0.501271
# ...                          ...                   ...                 ...
# 00.999500                2.59079             -2.550258            0.501263
# 00.999600                2.59079             -2.550258            0.501263
# 00.999700                2.59079             -2.550258            0.501263
# 00.999800                2.59079             -2.550258            0.501263
# 00.999900                2.59079             -2.550258            0.501263
#
# Exp Num       ...        exp 3000                                              \
# Name of meas  ... voltage_B_begin voltage_B_end voltage_C_begin voltage_C_end
# 00.150000     ...     289842.5242   282786.9567     289693.6626   282921.7733
# 00.150100     ...     289842.5242   282786.9567     289693.6626   282921.7733
# 00.150200     ...     289842.5242   282786.9567     289693.6626   282921.7733
# 00.150300     ...     289842.5242   282786.9567     289693.6626   282921.7733
# 00.150400     ...     289842.5242   282786.9567     289693.6626   282921.7733
# ...           ...             ...           ...             ...           ...
# 00.999500     ...     289842.5242   282786.9567     289693.6626   282921.7733
# 00.999600     ...     289842.5242   282786.9567     289693.6626   282921.7733
# 00.999700     ...     289842.5242   282786.9567     289693.6626   282921.7733
# 00.999800     ...     289842.5242   282786.9567     289693.6626   282921.7733
# 00.999900     ...     289842.5242   282786.9567     289693.6626   282921.7733
#
# Exp Num                                                                       \
# Name of meas voltage_A_angle_begin voltage_A_angle_end voltage_B_angle_begin
# 00.150000                -1.204092           -1.191631              2.982933
# 00.150100                -1.204092           -1.191631              2.982933
# 00.150200                -1.204092           -1.191631              2.982933
# 00.150300                -1.204092           -1.191631              2.982933
# 00.150400                -1.204092           -1.191631              2.982933
# ...                            ...                 ...                   ...
# 00.999500                -1.204092           -1.191631              2.982933
# 00.999600                -1.204092           -1.191631              2.982933
# 00.999700                -1.204092           -1.191631              2.982933
# 00.999800                -1.204092           -1.191631              2.982933
# 00.999900                -1.204092           -1.191631              2.982933
#
# Exp Num
# Name of meas voltage_B_angle_end voltage_C_angle_begin voltage_C_angle_end
# 00.150000               2.991544              0.887224            0.896469
# 00.150100               2.991544              0.887224            0.896469
# 00.150200               2.991544              0.887224            0.896469
# 00.150300               2.991544              0.887224            0.896469
# 00.150400               2.991544              0.887224            0.896469
# ...                          ...                   ...                 ...
# 00.999500               2.991544              0.887224            0.896469
# 00.999600               2.991544              0.887224            0.896469
# 00.999700               2.991544              0.887224            0.896469
# 00.999800               2.991544              0.887224            0.896469
# 00.999900               2.991544              0.887224            0.896469
#
# [8500 rows x 72000 columns]

# %%
del exp_data

# %%
columns_names = list(exp_data.columns)

print(columns_names[7][1].split('_'))
# Out:
# ['current', 'A', 'angle', 'end']

# %%
from alg_repository.data_importer import DataImporter as di
data = di('\t').main_process()

# %%
del data_end, data_end
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 del data_end, data_end
#
# NameError: name 'data_end' is not defined

# %%
import numpy as np

lib_meas = [
    'current',
    'voltage'
]

lib_phase = [
    'A',
    'B',
    'C'
]

lib_place = [
    'beg',
    'begin',
    'end'
]

for meas in lib_meas:
    for phase in lib_phase:
        for place in lib_place:
            data = []        
            for exp, key in exp_data.columns:
                if meas in key.split() or meas in key.split('_'):
                    if 'angle' not in key.split() or 'angle' not in key.split('_'): 
                        if phase in key.split('_') or phase in key.split():
                            if place in key.split('_') or place in key.split():
                                data.append([
                                    exp_data[exp, key].reset_index(drop=True).values
                                ])
                if phase == 'A':
                    if place == 'beg' or place == 'begin':
                        if meas == 'current':
                            data_cur_beg_A = np.array(data)
                        elif meas == 'voltage':
                            data_vol_beg_A = np.array(data)
                    elif place == 'end':
                        if meas == 'current':
                            data_cur_end_A = np.array(data)
                        elif meas == 'voltage':
                            data_vol_end_A = np.array(data)
                elif phase == 'B':
                    if place == 'beg' or place == 'begin':
                        if meas == 'current':
                            data_cur_beg_B = np.array(data)
                            try:
                                data_cur_beg = np.concatenate((data_cur_beg_A, data_cur_beg_B), axis=1)
                            except:
                                pass
                        elif meas == 'voltage':
                            data_vol_beg_B = np.array(data)
                            try:
                                data_vol_beg = np.concatenate((data_vol_beg_A, data_vol_beg_B), axis=1)
                            except:
                                pass
                    elif place == 'end':
                        if meas == 'current':
                            data_cur_end_B = np.array(data)
                            try:
                                data_cur_end = np.concatenate((data_cur_end_A, data_cur_end_B), axis=1)
                            except:
                                pass
                        elif meas == 'voltage':
                            data_vol_end_B = np.array(data)
                            try:
                                data_vol_end = np.concatenate((data_vol_end_A, data_vol_end_B), axis=1)
                            except:
                                pass
                elif phase == 'C':
                    if place == 'beg' or place == 'begin':
                        if meas == 'current':
                            data_cur_beg_C = np.array(data)
                            try:
                                data_cur_beg = np.concatenate((data_cur_beg_A, data_cur_beg_B, data_cur_beg_C), axis=1)
                            except:
                                pass
                        elif meas == 'voltage':
                            data_vol_beg_C = np.array(data)
                            try:
                                data_vol_beg = np.concatenate((data_vol_beg_A, data_vol_beg_B, data_vol_beg_C), axis=1)
                            except:
                                pass
                    elif place == 'end':
                        if meas == 'current':
                            data_cur_end_C = np.array(data)
                            try:
                                data_cur_end = np.concatenate((data_cur_end_A, data_cur_end_B, data_cur_end_C), axis=1)
                            except:
                                pass
                        elif meas == 'voltage':
                            data_vol_end_C = np.array(data)
                            try:
                                data_vol_end = np.concatenate((data_vol_end_A, data_vol_end_B, data_vol_end_C), axis=1)
                            except:
                                pass
            data = [] 
            for exp, key in exp_data.columns:
                if meas in key.split() or meas in key.split('_'):
                    if 'angle' in key.split() or 'angle' in key.split('_'): 
                        if phase in key.split('_') or phase in key.split():
                            if place in key.split('_') or place in key.split():
                                data.append([
                                    exp_data[exp, key].reset_index(drop=True).values
                                ]) 
                if phase == 'A' and meas == 'cuurent':
                    if place == 'beg' or place == 'begin':
                        data_cur_beg_ang_A = np.array(data)
                    elif place == 'end':
                        data_cur_end_ang_A = np.array(data)
                elif phase == 'B' and meas == 'cuurent':
                    if place == 'beg' or place == 'begin':
                        data_cur_beg_ang_B = np.array(data)
                        try:
                            data_cur_beg_ang = np.concatenate((data_cur_beg_ang_A, data_cur_beg_ang_B), axis=1)
                        except:
                            pass
                    elif place == 'end':
                        data_cur_end_ang_B = np.array(data)
                        try:
                            data_cur_end_ang = np.concatenate((data_cur_end_ang_A, data_cur_end_ang_B), axis=1)
                        except:
                            pass
                elif phase == 'C' and meas == 'cuurent':
                    if place == 'beg' or place == 'begin':
                        data_cur_beg_ang_C = np.array(data)
                        try:
                            data_cur_beg_ang = np.concatenate((data_cur_beg_ang_A, 
                                                               data_cur_beg_ang_B, data_cur_beg_ang_C), axis=1)
                        except:
                            pass
                    elif place == 'end':
                        data_cur_end_ang_C = np.array(data)
                        try:
                            data_cur_end_ang = np.concatenate((data_cur_end_ang_A, 
                                                               data_cur_end_ang_B, data_cur_end_ang_C), axis=1)
                        except:
                            pass
                elif phase == 'A' and meas == 'voltage':
                    if place == 'beg' or place == 'begin':
                        data_vol_beg_ang_A = np.array(data)
                    elif place == 'end':
                        data_vol_end_ang_A = np.array(data)
                elif phase == 'B' and meas == 'voltage':
                    if place == 'beg' or place == 'begin':
                        data_vol_beg_ang_B = np.array(data)
                        try:
                            data_vol_beg_ang = np.concatenate((data_vol_beg_ang_A, data_vol_beg_ang_B), axis=1)
                        except:
                            pass
                    elif place == 'end':
                        data_vol_end_ang_B = np.array(data)
                        try:
                            data_vol_end_ang = np.concatenate((data_vol_end_ang_A, data_vol_end_ang_B), axis=1)
                        except:
                            pass
                elif phase == 'C' and meas == 'voltage':
                    if place == 'beg' or place == 'begin':
                        data_vol_beg_ang_C = np.array(data)
                        try:
                            data_vol_beg_ang = np.concatenate((data_vol_beg_ang_A, 
                                                               data_vol_beg_ang_B, data_vol_beg_ang_C), axis=1)
                        except:
                            pass
                    elif place == 'end':
                        data_vol_end_ang_C = np.array(data)
                        try:
                            data_vol_end_ang = np.concatenate((data_vol_end_ang_A, 
                                                               data_vol_end_ang_B, data_vol_end_ang_C), axis=1)
                        except:
                            pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 59
#      57 elif place == 'end':
#      58     if meas == 'current':
# ---> 59         data_cur_end_B = np.array(data)
#      60         try:
#      61             data_cur_end = np.concatenate((data_cur_end_A, data_cur_end_B), axis=1)
#
# KeyboardInterrupt:

# %%
del data_current_A

# %%
print(exp_data.columns)
# Out:
# MultiIndex([(   'exp 1',         'current A beg'),
#             (   'exp 1',         'current A end'),
#             (   'exp 1',         'current B beg'),
#             (   'exp 1',         'current B end'),
#             (   'exp 1',         'current C beg'),
#             (   'exp 1',         'current C end'),
#             (   'exp 1', 'current_A_angle_begin'),
#             (   'exp 1',   'current_A_angle_end'),
#             (   'exp 1', 'current_B_angle_begin'),
#             (   'exp 1',   'current_B_angle_end'),
#             ...
#             ('exp 3000',       'voltage_B_begin'),
#             ('exp 3000',         'voltage_B_end'),
#             ('exp 3000',       'voltage_C_begin'),
#             ('exp 3000',         'voltage_C_end'),
#             ('exp 3000', 'voltage_A_angle_begin'),
#             ('exp 3000',   'voltage_A_angle_end'),
#             ('exp 3000', 'voltage_B_angle_begin'),
#             ('exp 3000',   'voltage_B_angle_end'),
#             ('exp 3000', 'voltage_C_angle_begin'),
#             ('exp 3000',   'voltage_C_angle_end')],
#            names=['Exp Num', 'Name of meas'], length=72000)

# %%
from alg_repository.TSC_forest_model import TimeSeriesClassifierForest as tsc
import numpy as np
base_estimator=None,
n_estimators=200,
n_intervals="sqrt",
min_interval_length=3,
max_interval_length=np.inf,
time_limit_in_minutes=None,
contract_max_n_estimators=500,
random_state=None,
n_jobs=1,
parallel_backend= "multiprocessin"

config = {
     'base_estimator': base_estimator,
     'n_estimators': n_estimators,
     'n_intervals': n_intervals,
     'min_interval_length': min_interval_length,
     'max_interval_length': max_interval_length,
     'time_limit_in_minutes': time_limit_in_minutes,
     'contract_max_n_estimators': contract_max_n_estimators,
     'random_state': random_state,
     'n_jobs': n_jobs,
     'parallel_backend': parallel_backend
}
config['n_jobs'][0]
# Out:
# 1

# %%
X = np.array([
    1,2,3,4,5
])
Y = np.array([
    1,2,3,4,5
])
model = tsc(config, X, Y)

data = model.data_preprocess()

print(data.X_train, ' ', data.Y_train, ' ', data.X_test, ' ', data.Y_test)

# %%
import numpy as np
from main import LearnProcess as lp
ml = lp('current begin')

X = ml.trainData()
Y = ml.aimData()

# %%
print(Y.flatten())
# Out:
# [18 18 18 ...  6 17  1]

# %%
import numpy as np
from main import LearnProcess as lp


model_1 = lp('current begin').fit()
# Out:
# Training the model:  current begin
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.31166666666666665
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        24
#            2       0.14      0.12      0.13        66
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00        15
#            5       0.00      0.00      0.00        29
#            6       0.16      0.13      0.14       126
#            7       0.00      0.00      0.00         4
#            9       0.00      0.00      0.00         8
#           10       0.00      0.00      0.00         7
#           11       1.00      0.05      0.10        19
#           12       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         2
#           17       0.00      0.00      0.00        33
#           18       0.38      0.67      0.49       240
#
#     accuracy                           0.31       600
#    macro avg       0.12      0.07      0.06       600
# weighted avg       0.23      0.31      0.24       600
# Я ТВОЙ РОТ ЕБАЛ!!!!

# %%
from main import LearnProcess as lp
text = lp().FullExpProcess()
print(text)
# Out:
# Training the model:  current begin
# Accuracy: 0.315
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        24
#            2       0.08      0.08      0.08        66
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00        15
#            5       0.00      0.00      0.00        29
#            6       0.20      0.20      0.20       126
#            7       0.00      0.00      0.00         4
#            9       0.00      0.00      0.00         8
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         2
#           17       0.00      0.00      0.00        33
#           18       0.39      0.66      0.49       240
#
#     accuracy                           0.32       600
#    macro avg       0.05      0.07      0.06       600
# weighted avg       0.21      0.32      0.25       600
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training the model:  current end
# Accuracy: 0.335
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        24
#            2       0.08      0.06      0.07        66
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00        15
#            5       0.00      0.00      0.00        29
#            6       0.19      0.18      0.19       126
#            7       0.00      0.00      0.00         4
#            9       0.00      0.00      0.00         8
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         2
#           17       0.00      0.00      0.00        33
#           18       0.41      0.72      0.53       240
#
#     accuracy                           0.34       600
#    macro avg       0.05      0.07      0.06       600
# weighted avg       0.21      0.34      0.26       600
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training the model:  voltage begin
# Accuracy: 0.3233333333333333
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        24
#            2       0.10      0.08      0.09        66
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00        15
#            5       0.00      0.00      0.00        29
#            6       0.20      0.20      0.20       126
#            7       0.00      0.00      0.00         4
#            9       1.00      0.12      0.22         8
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         2
#           17       0.00      0.00      0.00        33
#           18       0.39      0.68      0.50       240
#
#     accuracy                           0.32       600
#    macro avg       0.12      0.08      0.07       600
# weighted avg       0.22      0.32      0.25       600
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training the model:  voltage end
# Accuracy: 0.345
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        24
#            2       0.06      0.05      0.05        66
#            3       0.00      0.00      0.00        22
#            4       1.00      0.07      0.12        15
#            5       0.11      0.03      0.05        29
#            6       0.25      0.21      0.23       126
#            7       0.00      0.00      0.00         4
#            9       0.00      0.00      0.00         8
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         2
#           17       0.00      0.00      0.00        33
#           18       0.41      0.73      0.52       240
#
#     accuracy                           0.34       600
#    macro avg       0.13      0.08      0.07       600
# weighted avg       0.25      0.34      0.27       600
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training the model:  current angle begin
# Accuracy: 0.33166666666666667
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        24
#            2       0.07      0.06      0.07        66
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00        15
#            5       0.10      0.03      0.05        29
#            6       0.24      0.27      0.26       126
#            7       0.00      0.00      0.00         4
#            9       0.00      0.00      0.00         8
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         2
#           17       0.00      0.00      0.00        33
#           18       0.41      0.67      0.51       240
#
#     accuracy                           0.33       600
#    macro avg       0.06      0.07      0.06       600
# weighted avg       0.23      0.33      0.27       600
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training the model:  current angle end
# Accuracy: 0.33
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        24
#            2       0.08      0.08      0.08        66
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00        15
#            5       0.00      0.00      0.00        29
#            6       0.20      0.20      0.20       126
#            7       0.00      0.00      0.00         4
#            9       0.00      0.00      0.00         8
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         2
#           17       0.00      0.00      0.00        33
#           18       0.42      0.70      0.52       240
#
#     accuracy                           0.33       600
#    macro avg       0.05      0.07      0.06       600
# weighted avg       0.22      0.33      0.26       600
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training the model:  voltage angle begin
# Accuracy: 0.32
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        24
#            2       0.06      0.05      0.05        66
#            3       0.50      0.05      0.08        22
#            4       0.00      0.00      0.00        15
#            5       0.00      0.00      0.00        29
#            6       0.20      0.21      0.21       126
#            7       0.00      0.00      0.00         4
#            9       0.00      0.00      0.00         8
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         2
#           17       0.00      0.00      0.00        33
#           18       0.39      0.68      0.50       240
#
#     accuracy                           0.32       600
#    macro avg       0.08      0.07      0.06       600
# weighted avg       0.23      0.32      0.25       600
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training the model:  voltage angle end
# Accuracy: 0.335
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        24
#            2       0.07      0.06      0.07        66
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00        15
#            5       0.00      0.00      0.00        29
#            6       0.24      0.25      0.25       126
#            7       0.00      0.00      0.00         4
#            9       0.00      0.00      0.00         8
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         2
#           17       0.00      0.00      0.00        33
#           18       0.41      0.69      0.51       240
#
#     accuracy                           0.34       600
#    macro avg       0.05      0.07      0.06       600
# weighted avg       0.22      0.34      0.26       600
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Могло быть лучше но так получилось

# %%
import matplotlib.pyplot as plt
from alg_repository.data_importer import DataImporter as di
data = di().main_process()
ax1 = plt.plot(data)

# %%
model_2 = lp('current end').fit()
model_3 = lp('voltage begin').fit()
model_4 = lp('voltage end').fit()

# %%
model_5 = lp('current begin angle').fit()
model_6 = lp('current end angle').fit()
model_7 = lp('voltage begin angle').fit()
model_8 = lp('voltage end angle').fit()
# Out:
# Training the model:  current begin angle
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model_5 = lp('current begin angle').fit()
#       2 model_6 = lp('current end angle').fit()
#       3 model_7 = lp('voltage begin angle').fit()
#
# File c:\Users\Vlad Titov\Desktop\Work\fault_location_machine_learning\main.py:345, in LearnProcess.fit(self)
#     343 X = LearnProcess.trainData(self)
#     344 Y = LearnProcess.aimData(self)
# --> 345 model = tscf(config, X, Y).main()
#     346 return model
#
# File c:\Users\Vlad Titov\Desktop\Work\fault_location_machine_learning\alg_repository\TSC_forest_model.py:146, in TimeSeriesClassifierForest.main(self)
#     133 """
#     134 Executes the main workflow of the time series classification model.
#     135
#    (...)
#     143     TimeSeriesForestClassifier: The trained time series classification model.
#     144 """
#     145 self = TimeSeriesClassifierForest.data_preprocess(self)
# --> 146 self = TimeSeriesClassifierForest.train_model(self)
#     147 TimeSeriesClassifierForest.test_model(self)
#     148 return self.model
#
# File c:\Users\Vlad Titov\Desktop\Work\fault_location_machine_learning\alg_repository\TSC_forest_model.py:96, in TimeSeriesClassifierForest.train_model(self)
#      82 config = self.config
#      84 model = TimeSeriesForestClassifier(
#      85     base_estimator=config['base_estimator'][0],
#      86     n_estimators=config['n_estimators'][0],
#    (...)
#      94     parallel_backend= config['parallel_backend']
#      95 )
# ---> 96 model.fit(X_train, Y_train)
#      97 self.model = model
#      98 return self
#
# File c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\aeon\classification\base.py:129, in BaseClassifier.fit(self, X, y)
#     126 X, y, single_class = self._fit_setup(X, y)
#     128 if not single_class:
# --> 129     self._fit(X, y)
#     131 self.fit_time_ = int(round(time.time() * 1000)) - start
#     132 # this should happen last
#
# File c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\aeon\classification\interval_based\_tsf.py:186, in TimeSeriesForestClassifier._fit(self, X, y)
#     185 def _fit(self, X, y):
# --> 186     return super()._fit(X, y)
#
# File c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\aeon\base\estimator\interval_based\base_interval_forest.py:224, in BaseIntervalForest._fit(self, X, y)
#     222     self._transformed_data = self._fit_forest(X, y, save_transformed_data=True)
#     223 else:
# --> 224     self._fit_forest(X, y)
#     226 return self
#
# File c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\aeon\base\estimator\interval_based\base_interval_forest.py:844, in BaseIntervalForest._fit_forest(self, X, y, save_transformed_data)
#     841 else:
#     842     self._n_estimators = self.n_estimators
# --> 844     fit = Parallel(
#     845         n_jobs=self._n_jobs,
#     846         backend=self.parallel_backend,
#     847         prefer="threads",
#     848     )(
#     849         delayed(self._fit_estimator)(
#     850             Xt,
#     851             y,
#     852             rng.randint(np.iinfo(np.int32).max),
#     853             save_transformed_data=save_transformed_data,
#     854         )
#     855         for _ in range(self._n_estimators)
#     856     )
#     858     (
#     859         self.estimators_,
#     860         self.intervals_,
#     861         transformed_intervals,
#     862     ) = zip(*fit)
#     864 return transformed_intervals
#
# File c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File c:\Users\Vlad Titov\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
from alg_repository.TSC_forest_model import TimeSeriesClassifierForest as tsc

de = tsc(config, X, Y)

data = de.data_preprocess()
